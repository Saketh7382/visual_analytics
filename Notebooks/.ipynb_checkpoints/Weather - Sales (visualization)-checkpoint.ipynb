# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
#read excel sheet
xls = pd.ExcelFile('../AI-ML Tractor Analytics/DataSet.xlsx')
sales = pd.read_excel(xls,'Sales Data')
historic = pd.read_excel(xls,'HISTORY_DAY')
climatology = pd.read_excel(xls,'CLIMATOLOGY_DAY')
forecast = pd.read_excel(xls,'FORECAST_DAY')

# %%
temp = historic.copy()

# %%
sales.head()
# Out:
#    TIME_DIM_KEY  SCRUB_STORE_NO  SALES_UNITS
# 0      20160102               1          759
# 1      20160103               1          486
# 2      20160104               1          326
# 3      20160105               1          395
# 4      20160106               1          478

# %%
historic.head()
# Out:
#    SCRUB_STORE_NO COUNTRY DATE_VALID_STD  DOY_STD  MIN_TEMPERATURE_AIR_2M_F  \
# 0               1      US     2016-01-02        2                      26.5
# 1               1      US     2016-01-03        3                      26.0
# 2               1      US     2016-01-04        4                       8.3
# 3               1      US     2016-01-05        5                       6.2
# 4               1      US     2016-01-06        6                      24.7
#
#    AVG_TEMPERATURE_AIR_2M_F  MAX_TEMPERATURE_AIR_2M_F  \
# 0                      30.4                      34.5
# 1                      29.1                      31.6
# 2                      19.2                      25.7
# 3                      19.1                      28.7
# 4                      29.6                      35.7
#
#    MIN_TEMPERATURE_WETBULB_2M_F  AVG_TEMPERATURE_WETBULB_2M_F  \
# 0                          25.1                          28.7
# 1                          24.5                          27.2
# 2                           7.9                          17.8
# 3                           6.0                          18.0
# 4                          23.7                          27.8
#
#    MAX_TEMPERATURE_WETBULB_2M_F  ...  TOT_PRECIPITATION_IN  TOT_SNOWFALL_IN  \
# 0                          32.5  ...                   0.0              0.0
# 1                          30.2  ...                   0.0              0.0
# 2                          25.3  ...                   0.0              0.0
# 3                          27.2  ...                   0.0              0.0
# 4                          33.2  ...                   0.0              0.0
#
#    TOT_SNOWDEPTH_IN  MIN_CLOUD_COVER_TOT_PCT  AVG_CLOUD_COVER_TOT_PCT  \
# 0              16.1                        0                       57
# 1              15.4                       73                       94
# 2              15.5                       11                       50
# 3              15.3                       19                       81
# 4              15.2                        0                       63
#
#    MAX_CLOUD_COVER_TOT_PCT  MIN_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                      100                               0
# 1                      100                               0
# 2                       94                               0
# 3                       99                               0
# 4                      100                               0
#
#    AVG_RADIATION_SOLAR_TOTAL_WPM2  MAX_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                            32.3                           132.0
# 1                            49.6                           236.0
# 2                            93.2                           415.0
# 3                            52.6                           214.0
# 4                            80.3                           383.0
#
#    TOT_RADIATION_SOLAR_TOTAL_WPM2
# 0                           776.0
# 1                          1190.0
# 2                          2238.0
# 3                          1262.0
# 4                          1928.0
#
# [5 rows x 59 columns]

# %%
rows = historic.shape[0]
vals = list()
print("Processing: 0%[",end="")
p = rows//100
for i in range(rows):
    if i%p == 0:
        print("=>",end="")
    s = "".join(str(temp["DATE_VALID_STD"][i]).split()[0].split("-"))
    s = s + "-" + str(temp["SCRUB_STORE_NO"][i])
    vals.append(s)
print("=>]100%")
# Out:
# Processing: 0%[=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>]100%

# %%
historic["unique_ID"] = vals

# %%
historic.head()
# Out:
#    SCRUB_STORE_NO COUNTRY DATE_VALID_STD  DOY_STD  MIN_TEMPERATURE_AIR_2M_F  \
# 0               1      US     2016-01-02        2                      26.5
# 1               1      US     2016-01-03        3                      26.0
# 2               1      US     2016-01-04        4                       8.3
# 3               1      US     2016-01-05        5                       6.2
# 4               1      US     2016-01-06        6                      24.7
#
#    AVG_TEMPERATURE_AIR_2M_F  MAX_TEMPERATURE_AIR_2M_F  \
# 0                      30.4                      34.5
# 1                      29.1                      31.6
# 2                      19.2                      25.7
# 3                      19.1                      28.7
# 4                      29.6                      35.7
#
#    MIN_TEMPERATURE_WETBULB_2M_F  AVG_TEMPERATURE_WETBULB_2M_F  \
# 0                          25.1                          28.7
# 1                          24.5                          27.2
# 2                           7.9                          17.8
# 3                           6.0                          18.0
# 4                          23.7                          27.8
#
#    MAX_TEMPERATURE_WETBULB_2M_F  ...  TOT_SNOWFALL_IN  TOT_SNOWDEPTH_IN  \
# 0                          32.5  ...              0.0              16.1
# 1                          30.2  ...              0.0              15.4
# 2                          25.3  ...              0.0              15.5
# 3                          27.2  ...              0.0              15.3
# 4                          33.2  ...              0.0              15.2
#
#    MIN_CLOUD_COVER_TOT_PCT  AVG_CLOUD_COVER_TOT_PCT  MAX_CLOUD_COVER_TOT_PCT  \
# 0                        0                       57                      100
# 1                       73                       94                      100
# 2                       11                       50                       94
# 3                       19                       81                       99
# 4                        0                       63                      100
#
#    MIN_RADIATION_SOLAR_TOTAL_WPM2  AVG_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                               0                            32.3
# 1                               0                            49.6
# 2                               0                            93.2
# 3                               0                            52.6
# 4                               0                            80.3
#
#    MAX_RADIATION_SOLAR_TOTAL_WPM2  TOT_RADIATION_SOLAR_TOTAL_WPM2   unique_ID
# 0                           132.0                           776.0  20160102-1
# 1                           236.0                          1190.0  20160103-1
# 2                           415.0                          2238.0  20160104-1
# 3                           214.0                          1262.0  20160105-1
# 4                           383.0                          1928.0  20160106-1
#
# [5 rows x 60 columns]

# %%
temp = sales.copy()

# %%
rows = sales.shape[0]
vals = list()
print("Processing: 0%[",end="")
p = rows//100
for i in range(rows):
    if i%p == 0:
        print("=>",end="")
    s = str(temp["TIME_DIM_KEY"][i]) + "-" + str(temp["SCRUB_STORE_NO"][i])
    vals.append(s)
print("=>]100%")
# Out:
# Processing: 0%[=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>]100%

# %%
sales["unique_ID"] = vals

# %%
sales.head()
# Out:
#    TIME_DIM_KEY  SCRUB_STORE_NO  SALES_UNITS   unique_ID
# 0      20160102               1          759  20160102-1
# 1      20160103               1          486  20160103-1
# 2      20160104               1          326  20160104-1
# 3      20160105               1          395  20160105-1
# 4      20160106               1          478  20160106-1

# %%
historic.iloc[:,3:].head()
# Out:
#    DOY_STD  MIN_TEMPERATURE_AIR_2M_F  AVG_TEMPERATURE_AIR_2M_F  \
# 0        2                      26.5                      30.4
# 1        3                      26.0                      29.1
# 2        4                       8.3                      19.2
# 3        5                       6.2                      19.1
# 4        6                      24.7                      29.6
#
#    MAX_TEMPERATURE_AIR_2M_F  MIN_TEMPERATURE_WETBULB_2M_F  \
# 0                      34.5                          25.1
# 1                      31.6                          24.5
# 2                      25.7                           7.9
# 3                      28.7                           6.0
# 4                      35.7                          23.7
#
#    AVG_TEMPERATURE_WETBULB_2M_F  MAX_TEMPERATURE_WETBULB_2M_F  \
# 0                          28.7                          32.5
# 1                          27.2                          30.2
# 2                          17.8                          25.3
# 3                          18.0                          27.2
# 4                          27.8                          33.2
#
#    MIN_TEMPERATURE_DEWPOINT_2M_F  AVG_TEMPERATURE_DEWPOINT_2M_F  \
# 0                           21.9                           25.5
# 1                           18.6                           23.3
# 2                            6.1                           13.5
# 3                            5.2                           15.3
# 4                           21.1                           24.4
#
#    MAX_TEMPERATURE_DEWPOINT_2M_F  ...  TOT_SNOWFALL_IN  TOT_SNOWDEPTH_IN  \
# 0                           29.8  ...              0.0              16.1
# 1                           27.9  ...              0.0              15.4
# 2                           24.9  ...              0.0              15.5
# 3                           24.4  ...              0.0              15.3
# 4                           29.2  ...              0.0              15.2
#
#    MIN_CLOUD_COVER_TOT_PCT  AVG_CLOUD_COVER_TOT_PCT  MAX_CLOUD_COVER_TOT_PCT  \
# 0                        0                       57                      100
# 1                       73                       94                      100
# 2                       11                       50                       94
# 3                       19                       81                       99
# 4                        0                       63                      100
#
#    MIN_RADIATION_SOLAR_TOTAL_WPM2  AVG_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                               0                            32.3
# 1                               0                            49.6
# 2                               0                            93.2
# 3                               0                            52.6
# 4                               0                            80.3
#
#    MAX_RADIATION_SOLAR_TOTAL_WPM2  TOT_RADIATION_SOLAR_TOTAL_WPM2   unique_ID
# 0                           132.0                           776.0  20160102-1
# 1                           236.0                          1190.0  20160103-1
# 2                           415.0                          2238.0  20160104-1
# 3                           214.0                          1262.0  20160105-1
# 4                           383.0                          1928.0  20160106-1
#
# [5 rows x 57 columns]

# %%
dataset = sales.merge(historic.iloc[:,3:], on="unique_ID", how="left")

# %%
dataset.head()
# Out:
#    TIME_DIM_KEY  SCRUB_STORE_NO  SALES_UNITS   unique_ID  DOY_STD  \
# 0      20160102               1          759  20160102-1        2
# 1      20160103               1          486  20160103-1        3
# 2      20160104               1          326  20160104-1        4
# 3      20160105               1          395  20160105-1        5
# 4      20160106               1          478  20160106-1        6
#
#    MIN_TEMPERATURE_AIR_2M_F  AVG_TEMPERATURE_AIR_2M_F  \
# 0                      26.5                      30.4
# 1                      26.0                      29.1
# 2                       8.3                      19.2
# 3                       6.2                      19.1
# 4                      24.7                      29.6
#
#    MAX_TEMPERATURE_AIR_2M_F  MIN_TEMPERATURE_WETBULB_2M_F  \
# 0                      34.5                          25.1
# 1                      31.6                          24.5
# 2                      25.7                           7.9
# 3                      28.7                           6.0
# 4                      35.7                          23.7
#
#    AVG_TEMPERATURE_WETBULB_2M_F  ...  TOT_PRECIPITATION_IN  TOT_SNOWFALL_IN  \
# 0                          28.7  ...                   0.0              0.0
# 1                          27.2  ...                   0.0              0.0
# 2                          17.8  ...                   0.0              0.0
# 3                          18.0  ...                   0.0              0.0
# 4                          27.8  ...                   0.0              0.0
#
#    TOT_SNOWDEPTH_IN  MIN_CLOUD_COVER_TOT_PCT  AVG_CLOUD_COVER_TOT_PCT  \
# 0              16.1                        0                       57
# 1              15.4                       73                       94
# 2              15.5                       11                       50
# 3              15.3                       19                       81
# 4              15.2                        0                       63
#
#    MAX_CLOUD_COVER_TOT_PCT  MIN_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                      100                               0
# 1                      100                               0
# 2                       94                               0
# 3                       99                               0
# 4                      100                               0
#
#    AVG_RADIATION_SOLAR_TOTAL_WPM2  MAX_RADIATION_SOLAR_TOTAL_WPM2  \
# 0                            32.3                           132.0
# 1                            49.6                           236.0
# 2                            93.2                           415.0
# 3                            52.6                           214.0
# 4                            80.3                           383.0
#
#    TOT_RADIATION_SOLAR_TOTAL_WPM2
# 0                           776.0
# 1                          1190.0
# 2                          2238.0
# 3                          1262.0
# 4                          1928.0
#
# [5 rows x 60 columns]

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %% [markdown]
# # code check

# %%
second_data_col = "AVG_TEMPERATURE_WETBULB_2M_F"
store = 10
smooth_factor = 20

'''---------------------------------------------------------------------------------------------------------'''

    sales_units = dataset[dataset["SCRUB_STORE_NO"] == store]["SALES_UNITS"].to_numpy()
    second_data = dataset[dataset["SCRUB_STORE_NO"] == store][second_data_col].to_numpy()

    smooth_sales_units = smooth(sales_units,smooth_factor)
    smooth_second_data = smooth(second_data,smooth_factor)

    y = [i for i in range(1,len(second_data)+1)]

# %%
plt.plot(y,smooth_sales_units,color ='orange')
plt.plot(y,smooth_second_data,color ='red')
plt.title(second_data_col)
plt.show()

# %% [markdown]
# # Plotting

# %%
#get all the columns
cols = list(dataset.columns)[5:]

# %%
def plot(second_data_col, store = 1, smooth_factor = 10):
    
    sales_units = dataset[dataset["SCRUB_STORE_NO"] == store]["SALES_UNITS"].to_numpy()
    second_data = dataset[dataset["SCRUB_STORE_NO"] == store][second_data_col].to_numpy()

    smooth_sales_units = smooth(sales_units,smooth_factor)
    smooth_second_data = smooth(second_data,smooth_factor)

    y = [i for i in range(1,len(second_data)+1)]
