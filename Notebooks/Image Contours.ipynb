# %%
import cv2

# %%
image = cv2.imread("Scrub_Store_3.jpg")

img_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(img_gray, 50, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(image=thresh, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_SIMPLE)

image_copy = image.copy()
# print(contours)
cv2.drawContours(image=image_copy, contours=contours, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)

cv2.imshow("",image_copy)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

# Read the original image
img = cv2.imread('Scrub_Store_4.jpg') 
# Display original image
cv2.imshow('Original', img)
cv2.waitKey(0)

# Convert to graycsale
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
# Blur the image for better edge detection
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0) 

# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=100, threshold2=200) # Canny Edge Detection
# Display Canny Edge Detection Image
cv2.imshow('Canny Edge Detection', edges)
cv2.waitKey(0)

contours, hierarchy = cv2.findContours(image=edges, mode=cv2.RETR_TREE, method=cv2.CHAIN_APPROX_SIMPLE)

cont_img = img.copy()
# print(contours)
c = sorted(contours, key = cv2.contourArea)
print(c)
for i in contours:
    if cv2.contourArea(i) > cv2.arcLength(i, True):
        cv2.drawContours(image=cont_img, contours=i, contourIdx=-1, color=(0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
        
cv2.imshow("",cont_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [array([[[529, 526]],
#
#        [[530, 526]]], dtype=int32), array([[[ 68, 500]]], dtype=int32), array([[[ 63, 498]]], dtype=int32), array([[[ 39, 489]],
#
#        [[ 38, 490]],
#
#        [[ 14, 490]],
#
#        [[ 13, 491]],
#
#        [[ 13, 492]],
#
#        [[ 12, 493]],
#
#        [[ 12, 496]],
#
#        [[ 13, 497]],
#
#        [[ 13, 500]],
#
#        [[ 13, 497]],
#
#        [[ 12, 496]],
#
#        [[ 12, 493]],
#
#        [[ 13, 492]],
#
#        [[ 13, 491]],
#
#        [[ 14, 490]],
#
#        [[ 38, 490]],
#
#        [[ 39, 489]],
#
#        [[ 44, 489]],
#
#        [[ 45, 490]],
#
#        [[ 47, 490]],
#
#        [[ 48, 489]],
#
#        [[ 60, 489]],
#
#        [[ 48, 489]],
#
#        [[ 47, 490]],
#
#        [[ 45, 490]],
#
#        [[ 44, 489]]], dtype=int32), array([[[ 93, 443]]], dtype=int32), array([[[109, 469]],
#
#        [[109, 473]]], dtype=int32), array([[[ 69, 447]],
#
#        [[ 70, 447]]], dtype=int32), array([[[  2, 405]],
#
#        [[  1, 406]],
#
#        [[  2, 405]],
#
#        [[  3, 405]]], dtype=int32), array([[[ 95, 407]],
#
#        [[101, 407]]], dtype=int32), array([[[133, 384]],
#
#        [[134, 385]],
#
#        [[138, 385]],
#
#        [[139, 386]],
#
#        [[140, 386]],
#
#        [[139, 386]],
#
#        [[138, 385]],
#
#        [[134, 385]]], dtype=int32), array([[[455, 382]],
#
#        [[454, 383]],
#
#        [[423, 383]],
#
#        [[422, 384]],
#
#        [[394, 384]],
#
#        [[393, 385]],
#
#        [[390, 385]],
#
#        [[389, 384]],
#
#        [[387, 384]],
#
#        [[386, 385]],
#
#        [[353, 385]],
#
#        [[386, 385]],
#
#        [[387, 384]],
#
#        [[389, 384]],
#
#        [[390, 385]],
#
#        [[393, 385]],
#
#        [[394, 384]],
#
#        [[422, 384]],
#
#        [[423, 383]],
#
#        [[454, 383]],
#
#        [[455, 382]],
#
#        [[458, 382]]], dtype=int32), array([[[163, 381]],
#
#        [[166, 381]]], dtype=int32), array([[[120, 383]],
#
#        [[125, 383]],
#
#        [[126, 384]],
#
#        [[125, 383]]], dtype=int32), array([[[156, 379]],
#
#        [[156, 380]]], dtype=int32), array([[[ 75, 378]],
#
#        [[ 76, 378]]], dtype=int32), array([[[291, 375]]], dtype=int32), array([[[493, 372]],
#
#        [[494, 373]]], dtype=int32), array([[[397, 371]]], dtype=int32), array([[[417, 370]],
#
#        [[419, 370]]], dtype=int32), array([[[107, 365]],
#
#        [[107, 369]],
#
#        [[108, 370]],
#
#        [[108, 375]],
#
#        [[109, 376]],
#
#        [[109, 377]],
#
#        [[108, 378]],
#
#        [[109, 379]],
#
#        [[109, 381]],
#
#        [[108, 382]],
#
#        [[108, 383]],
#
#        [[108, 382]],
#
#        [[109, 381]],
#
#        [[109, 379]],
#
#        [[108, 378]],
#
#        [[109, 377]],
#
#        [[109, 376]],
#
#        [[108, 375]],
#
#        [[108, 370]],
#
#        [[107, 369]]], dtype=int32), array([[[ 67, 364]],
#
#        [[ 72, 364]]], dtype=int32), array([[[ 54, 346]],
#
#        [[ 55, 346]]], dtype=int32), array([[[371, 338]],
#
#        [[372, 338]]], dtype=int32), array([[[285, 338]]], dtype=int32), array([[[421, 329]],
#
#        [[422, 329]],
#
#        [[423, 330]],
#
#        [[422, 329]]], dtype=int32), array([[[411, 329]],
#
#        [[419, 329]]], dtype=int32), array([[[130, 328]],
#
#        [[130, 329]]], dtype=int32), array([[[194, 321]],
#
#        [[194, 323]]], dtype=int32), array([[[524, 320]],
#
#        [[529, 320]]], dtype=int32), array([[[168, 320]],
#
#        [[168, 324]]], dtype=int32), array([[[325, 318]]], dtype=int32), array([[[261, 318]],
#
#        [[263, 318]]], dtype=int32), array([[[415, 316]],
#
#        [[415, 320]]], dtype=int32), array([[[100, 313]],
#
#        [[101, 314]],
#
#        [[102, 314]],
#
#        [[101, 314]]], dtype=int32), array([[[428, 312]],
#
#        [[430, 312]]], dtype=int32), array([[[164, 310]],
#
#        [[164, 312]],
#
#        [[165, 313]],
#
#        [[164, 312]]], dtype=int32), array([[[298, 309]],
#
#        [[301, 309]]], dtype=int32), array([[[246, 308]]], dtype=int32), array([[[277, 307]],
#
#        [[278, 308]],
#
#        [[282, 308]],
#
#        [[278, 308]]], dtype=int32), array([[[ 74, 304]]], dtype=int32), array([[[ 85, 303]],
#
#        [[100, 303]]], dtype=int32), array([[[181, 352]],
#
#        [[182, 352]]], dtype=int32), array([[[271, 299]],
#
#        [[272, 299]]], dtype=int32), array([[[434, 298]],
#
#        [[435, 299]],
#
#        [[435, 305]],
#
#        [[435, 299]]], dtype=int32), array([[[173, 306]],
#
#        [[174, 306]]], dtype=int32), array([[[223, 296]],
#
#        [[223, 298]]], dtype=int32), array([[[207, 296]],
#
#        [[207, 298]]], dtype=int32), array([[[398, 294]],
#
#        [[398, 299]]], dtype=int32), array([[[108, 291]],
#
#        [[108, 292]]], dtype=int32), array([[[268, 289]],
#
#        [[270, 289]]], dtype=int32), array([[[493, 287]],
#
#        [[492, 288]],
#
#        [[493, 287]],
#
#        [[494, 288]],
#
#        [[498, 288]],
#
#        [[499, 287]],
#
#        [[501, 287]],
#
#        [[499, 287]],
#
#        [[498, 288]],
#
#        [[494, 288]]], dtype=int32), array([[[530, 286]],
#
#        [[530, 287]]], dtype=int32), array([[[251, 285]],
#
#        [[250, 286]],
#
#        [[227, 286]],
#
#        [[226, 287]],
#
#        [[221, 287]],
#
#        [[226, 287]],
#
#        [[227, 286]],
#
#        [[250, 286]],
#
#        [[251, 285]],
#
#        [[255, 285]]], dtype=int32), array([[[259, 281]],
#
#        [[260, 281]]], dtype=int32), array([[[149, 304]],
#
#        [[151, 304]],
#
#        [[152, 305]],
#
#        [[151, 304]]], dtype=int32), array([[[246, 280]],
#
#        [[251, 280]],
#
#        [[252, 281]],
#
#        [[253, 281]],
#
#        [[254, 280]],
#
#        [[253, 281]],
#
#        [[252, 281]],
#
#        [[251, 280]]], dtype=int32), array([[[140, 277]],
#
#        [[145, 277]]], dtype=int32), array([[[531, 275]],
#
#        [[537, 275]]], dtype=int32), array([[[511, 296]],
#
#        [[510, 297]],
#
#        [[509, 297]],
#
#        [[510, 297]],
#
#        [[511, 296]],
#
#        [[514, 296]]], dtype=int32), array([[[582, 268]],
#
#        [[583, 268]]], dtype=int32), array([[[476, 239]],
#
#        [[475, 240]],
#
#        [[476, 239]],
#
#        [[481, 239]],
#
#        [[482, 240]],
#
#        [[484, 240]],
#
#        [[482, 240]],
#
#        [[481, 239]]], dtype=int32), array([[[260, 236]],
#
#        [[265, 236]]], dtype=int32), array([[[238, 234]],
#
#        [[248, 234]]], dtype=int32), array([[[230, 226]]], dtype=int32), array([[[406, 220]],
#
#        [[406, 223]]], dtype=int32), array([[[408, 219]],
#
#        [[408, 223]]], dtype=int32), array([[[214, 209]],
#
#        [[214, 210]]], dtype=int32), array([[[212, 209]]], dtype=int32), array([[[466, 208]],
#
#        [[467, 208]]], dtype=int32), array([[[492, 205]],
#
#        [[493, 205]]], dtype=int32), array([[[251, 197]],
#
#        [[259, 197]]], dtype=int32), array([[[249, 197]]], dtype=int32), array([[[303, 196]],
#
#        [[305, 196]]], dtype=int32), array([[[475, 195]],
#
#        [[475, 196]]], dtype=int32), array([[[186, 190]],
#
#        [[185, 191]],
#
#        [[186, 190]],
#
#        [[191, 190]]], dtype=int32), array([[[467, 187]],
#
#        [[468, 187]]], dtype=int32), array([[[468, 185]],
#
#        [[469, 185]]], dtype=int32), array([[[224, 183]],
#
#        [[223, 184]],
#
#        [[220, 184]],
#
#        [[223, 184]],
#
#        [[224, 183]],
#
#        [[228, 183]],
#
#        [[229, 184]],
#
#        [[234, 184]],
#
#        [[229, 184]],
#
#        [[228, 183]]], dtype=int32), array([[[235, 176]]], dtype=int32), array([[[226, 176]],
#
#        [[227, 176]]], dtype=int32), array([[[504, 173]],
#
#        [[504, 174]]], dtype=int32), array([[[505, 171]],
#
#        [[506, 171]]], dtype=int32), array([[[519, 168]]], dtype=int32), array([[[379, 167]],
#
#        [[378, 168]],
#
#        [[371, 168]],
#
#        [[378, 168]]], dtype=int32), array([[[205, 167]]], dtype=int32), array([[[  0, 165]],
#
#        [[  6, 165]]], dtype=int32), array([[[183, 163]],
#
#        [[185, 163]],
#
#        [[186, 164]],
#
#        [[186, 165]],
#
#        [[187, 166]],
#
#        [[189, 166]],
#
#        [[187, 166]],
#
#        [[186, 165]],
#
#        [[186, 164]],
#
#        [[185, 163]]], dtype=int32), array([[[453, 189]]], dtype=int32), array([[[306, 155]],
#
#        [[305, 156]],
#
#        [[303, 156]],
#
#        [[305, 156]],
#
#        [[306, 155]],
#
#        [[307, 155]]], dtype=int32), array([[[477, 154]],
#
#        [[479, 154]]], dtype=int32), array([[[431, 153]],
#
#        [[432, 153]]], dtype=int32), array([[[560, 152]]], dtype=int32), array([[[ 25, 149]],
#
#        [[ 31, 149]]], dtype=int32), array([[[ 16, 144]],
#
#        [[ 32, 144]]], dtype=int32), array([[[427, 143]],
#
#        [[426, 144]]], dtype=int32), array([[[287, 142]],
#
#        [[286, 143]],
#
#        [[285, 143]],
#
#        [[284, 144]],
#
#        [[284, 147]],
#
#        [[284, 144]],
#
#        [[285, 143]],
#
#        [[286, 143]],
#
#        [[287, 142]],
#
#        [[288, 142]]], dtype=int32), array([[[365, 141]],
#
#        [[367, 141]]], dtype=int32), array([[[264, 189]],
#
#        [[266, 189]],
#
#        [[267, 190]],
#
#        [[271, 190]],
#
#        [[267, 190]],
#
#        [[266, 189]]], dtype=int32), array([[[243, 182]],
#
#        [[243, 187]],
#
#        [[244, 188]],
#
#        [[243, 187]]], dtype=int32), array([[[247, 174]]], dtype=int32), array([[[249, 171]]], dtype=int32), array([[[276, 158]],
#
#        [[276, 161]]], dtype=int32), array([[[381, 136]],
#
#        [[381, 139]]], dtype=int32), array([[[565, 134]],
#
#        [[565, 136]],
#
#        [[566, 137]],
#
#        [[565, 136]]], dtype=int32), array([[[475, 133]],
#
#        [[477, 133]]], dtype=int32), array([[[429, 132]],
#
#        [[430, 132]]], dtype=int32), array([[[487, 130]],
#
#        [[487, 132]]], dtype=int32), array([[[278, 128]],
#
#        [[278, 129]]], dtype=int32), array([[[112, 128]]], dtype=int32), array([[[111, 126]]], dtype=int32), array([[[357, 176]]], dtype=int32), array([[[356, 167]],
#
#        [[356, 173]]], dtype=int32), array([[[356, 165]],
#
#        [[357, 165]]], dtype=int32), array([[[  0, 123]],
#
#        [[  2, 123]]], dtype=int32), array([[[490, 120]],
#
#        [[490, 148]],
#
#        [[491, 149]],
#
#        [[491, 168]],
#
#        [[491, 149]],
#
#        [[490, 148]]], dtype=int32), array([[[314, 220]],
#
#        [[313, 221]],
#
#        [[310, 221]],
#
#        [[313, 221]],
#
#        [[314, 220]],
#
#        [[316, 220]]], dtype=int32), array([[[305, 220]],
#
#        [[305, 223]]], dtype=int32), array([[[180, 118]],
#
#        [[179, 119]],
#
#        [[151, 119]],
#
#        [[179, 119]],
#
#        [[180, 118]],
#
#        [[182, 118]]], dtype=int32), array([[[568, 306]],
#
#        [[571, 306]]], dtype=int32), array([[[564, 316]]], dtype=int32), array([[[564, 313]]], dtype=int32), array([[[553, 291]],
#
#        [[554, 291]]], dtype=int32), array([[[555, 276]],
#
#        [[554, 277]],
#
#        [[555, 278]],
#
#        [[556, 278]],
#
#        [[555, 278]],
#
#        [[554, 277]],
#
#        [[555, 276]],
#
#        [[558, 276]]], dtype=int32), array([[[358, 117]]], dtype=int32), array([[[376, 115]],
#
#        [[378, 115]]], dtype=int32), array([[[102, 114]],
#
#        [[104, 114]]], dtype=int32), array([[[330, 113]],
#
#        [[330, 114]]], dtype=int32), array([[[295, 109]]], dtype=int32), array([[[121, 108]],
#
#        [[126, 108]]], dtype=int32), array([[[ 99, 105]],
#
#        [[ 99, 108]]], dtype=int32), array([[[339, 103]],
#
#        [[339, 104]]], dtype=int32), array([[[367, 100]],
#
#        [[367, 102]]], dtype=int32), array([[[16, 99]],
#
#        [[22, 99]]], dtype=int32), array([[[276,  97]],
#
#        [[277,  97]]], dtype=int32), array([[[480,  96]],
#
#        [[479,  97]],
#
#        [[473,  97]],
#
#        [[479,  97]]], dtype=int32), array([[[217,  95]],
#
#        [[217,  96]]], dtype=int32), array([[[198,  95]],
#
#        [[198,  99]]], dtype=int32), array([[[367,  94]],
#
#        [[367,  95]]], dtype=int32), array([[[220,  94]],
#
#        [[220,  96]]], dtype=int32), array([[[409,  89]],
#
#        [[408,  90]],
#
#        [[408,  92]],
#
#        [[408,  90]],
#
#        [[409,  89]],
#
#        [[410,  89]]], dtype=int32), array([[[365,  89]]], dtype=int32), array([[[292,  86]],
#
#        [[294,  86]]], dtype=int32), array([[[499,  85]],
#
#        [[509,  85]]], dtype=int32), array([[[289,  85]],
#
#        [[290,  85]]], dtype=int32), array([[[309,  82]],
#
#        [[310,  82]]], dtype=int32), array([[[333,  94]],
#
#        [[333,  95]]], dtype=int32), array([[[305,  93]]], dtype=int32), array([[[298,  93]]], dtype=int32), array([[[372,  80]]], dtype=int32), array([[[11, 62]],
#
#        [[11, 63]]], dtype=int32), array([[[19, 55]],
#
#        [[20, 55]]], dtype=int32), array([[[41, 53]],
#
#        [[45, 53]]], dtype=int32), array([[[19, 53]],
#
#        [[22, 53]]], dtype=int32), array([[[431,  24]],
#
#        [[430,  25]],
#
#        [[431,  26]],
#
#        [[431,  27]],
#
#        [[430,  28]],
#
#        [[431,  27]],
#
#        [[431,  26]],
#
#        [[430,  25]]], dtype=int32), array([[[70,  1]],
#
#        [[71,  1]],
#
#        [[72,  2]],
#
#        [[72,  3]],
#
#        [[72,  2]],
#
#        [[73,  1]],
#
#        [[72,  2]],
#
#        [[71,  1]]], dtype=int32), array([[[489,   0]],
#
#        [[488,   1]],
#
#        [[488,   3]],
#
#        [[488,   1]]], dtype=int32), array([[[ 48, 505]],
#
#        [[ 48, 515]],
#
#        [[ 49, 516]],
#
#        [[ 49, 517]],
#
#        [[ 50, 518]],
#
#        [[ 49, 519]],
#
#        [[ 50, 519]],
#
#        [[ 50, 518]],
#
#        [[ 49, 517]],
#
#        [[ 49, 516]],
#
#        [[ 48, 515]]], dtype=int32), array([[[ 14, 462]],
#
#        [[ 14, 467]],
#
#        [[ 18, 467]],
#
#        [[ 15, 467]],
#
#        [[ 14, 466]]], dtype=int32), array([[[  8, 413]],
#
#        [[  8, 416]],
#
#        [[  9, 417]],
#
#        [[  9, 418]],
#
#        [[  8, 419]],
#
#        [[  7, 419]],
#
#        [[  6, 420]],
#
#        [[  4, 420]],
#
#        [[  3, 421]],
#
#        [[  1, 421]],
#
#        [[  3, 421]],
#
#        [[  4, 420]],
#
#        [[  6, 420]],
#
#        [[  7, 419]],
#
#        [[  9, 419]],
#
#        [[  9, 417]],
#
#        [[  8, 416]]], dtype=int32), array([[[  2, 399]],
#
#        [[  1, 400]],
#
#        [[  0, 400]],
#
#        [[  2, 400]]], dtype=int32), array([[[  5, 393]],
#
#        [[  4, 394]],
#
#        [[  0, 394]],
#
#        [[  5, 394]]], dtype=int32), array([[[462, 372]],
#
#        [[463, 373]],
#
#        [[463, 372]]], dtype=int32), array([[[310, 371]],
#
#        [[309, 372]],
#
#        [[307, 372]],
#
#        [[307, 374]],
#
#        [[307, 373]],
#
#        [[308, 372]],
#
#        [[309, 372]],
#
#        [[310, 371]],
#
#        [[311, 372]],
#
#        [[312, 372]],
#
#        [[311, 372]]], dtype=int32), array([[[375, 334]],
#
#        [[375, 337]],
#
#        [[374, 338]],
#
#        [[374, 339]],
#
#        [[373, 340]],
#
#        [[369, 340]],
#
#        [[368, 339]],
#
#        [[369, 340]],
#
#        [[374, 340]],
#
#        [[374, 338]],
#
#        [[375, 337]]], dtype=int32), array([[[433, 333]],
#
#        [[433, 334]],
#
#        [[434, 335]],
#
#        [[434, 346]],
#
#        [[434, 335]],
#
#        [[433, 334]],
#
#        [[434, 333]]], dtype=int32), array([[[374, 324]],
#
#        [[374, 325]],
#
#        [[375, 324]]], dtype=int32), array([[[294, 319]],
#
#        [[299, 319]],
#
#        [[300, 320]],
#
#        [[299, 321]],
#
#        [[298, 321]],
#
#        [[297, 322]],
#
#        [[296, 322]],
#
#        [[297, 322]],
#
#        [[298, 321]],
#
#        [[300, 321]],
#
#        [[300, 320]],
#
#        [[299, 319]]], dtype=int32), array([[[ 97, 353]],
#
#        [[ 97, 354]],
#
#        [[ 98, 353]]], dtype=int32), array([[[424, 292]],
#
#        [[424, 296]],
#
#        [[425, 296]],
#
#        [[426, 297]],
#
#        [[427, 297]],
#
#        [[428, 296]],
#
#        [[429, 297]],
#
#        [[431, 297]],
#
#        [[429, 297]],
#
#        [[428, 296]],
#
#        [[427, 297]],
#
#        [[426, 297]],
#
#        [[424, 295]]], dtype=int32), array([[[140, 286]],
#
#        [[141, 286]],
#
#        [[142, 287]],
#
#        [[141, 288]],
#
#        [[140, 288]],
#
#        [[141, 288]],
#
#        [[142, 287]],
#
#        [[142, 286]]], dtype=int32), array([[[262, 281]],
#
#        [[273, 281]],
#
#        [[274, 282]],
#
#        [[274, 281]]], dtype=int32), array([[[111, 277]],
#
#        [[111, 278]],
#
#        [[110, 279]],
#
#        [[111, 279]]], dtype=int32), array([[[414, 274]],
#
#        [[413, 275]],
#
#        [[412, 275]],
#
#        [[413, 275]],
#
#        [[414, 274]],
#
#        [[415, 274]],
#
#        [[416, 275]],
#
#        [[416, 274]]], dtype=int32), array([[[581, 265]],
#
#        [[581, 266]],
#
#        [[582, 265]],
#
#        [[583, 265]]], dtype=int32), array([[[500, 234]],
#
#        [[499, 235]],
#
#        [[496, 235]],
#
#        [[495, 236]],
#
#        [[493, 236]],
#
#        [[492, 235]],
#
#        [[493, 236]],
#
#        [[492, 237]],
#
#        [[491, 237]],
#
#        [[492, 238]],
#
#        [[492, 237]],
#
#        [[493, 236]],
#
#        [[495, 236]],
#
#        [[496, 237]],
#
#        [[496, 238]],
#
#        [[496, 237]],
#
#        [[495, 236]],
#
#        [[496, 235]],
#
#        [[499, 235]],
#
#        [[500, 234]],
#
#        [[501, 234]]], dtype=int32), array([[[ 37, 214]],
#
#        [[ 38, 214]],
#
#        [[ 39, 215]],
#
#        [[ 40, 215]],
#
#        [[ 41, 216]],
#
#        [[ 41, 215]],
#
#        [[ 39, 215]],
#
#        [[ 38, 214]]], dtype=int32), array([[[490, 204]],
#
#        [[490, 207]],
#
#        [[491, 207]],
#
#        [[490, 206]]], dtype=int32), array([[[502, 171]],
#
#        [[501, 172]],
#
#        [[502, 172]]], dtype=int32), array([[[223, 171]],
#
#        [[223, 172]],
#
#        [[224, 172]]], dtype=int32), array([[[  5, 170]],
#
#        [[  5, 171]],
#
#        [[  8, 171]],
#
#        [[  6, 171]]], dtype=int32), array([[[197, 159]],
#
#        [[198, 160]],
#
#        [[198, 159]]], dtype=int32), array([[[226, 156]],
#
#        [[226, 157]],
#
#        [[225, 158]],
#
#        [[225, 159]],
#
#        [[225, 158]],
#
#        [[227, 156]],
#
#        [[228, 156]]], dtype=int32), array([[[301, 146]],
#
#        [[301, 147]],
#
#        [[302, 146]],
#
#        [[303, 146]]], dtype=int32), array([[[427, 121]],
#
#        [[427, 124]],
#
#        [[427, 122]],
#
#        [[428, 121]]], dtype=int32), array([[[550, 275]],
#
#        [[551, 276]],
#
#        [[549, 278]],
#
#        [[551, 276]],
#
#        [[551, 275]]], dtype=int32), array([[[355, 117]],
#
#        [[356, 118]],
#
#        [[356, 119]],
#
#        [[359, 119]],
#
#        [[357, 119]]], dtype=int32), array([[[347, 116]],
#
#        [[346, 117]],
#
#        [[347, 117]]], dtype=int32), array([[[184, 115]],
#
#        [[184, 120]],
#
#        [[183, 121]],
#
#        [[178, 121]],
#
#        [[177, 122]],
#
#        [[145, 122]],
#
#        [[177, 122]],
#
#        [[178, 121]],
#
#        [[184, 121]]], dtype=int32), array([[[114, 112]],
#
#        [[114, 113]],
#
#        [[115, 112]],
#
#        [[116, 112]]], dtype=int32), array([[[250, 110]],
#
#        [[250, 111]],
#
#        [[251, 111]]], dtype=int32), array([[[ 59, 107]],
#
#        [[ 59, 110]],
#
#        [[ 59, 108]],
#
#        [[ 60, 107]],
#
#        [[ 62, 107]]], dtype=int32), array([[[285, 105]],
#
#        [[284, 106]],
#
#        [[284, 108]],
#
#        [[283, 109]],
#
#        [[283, 110]],
#
#        [[283, 109]],
#
#        [[284, 108]],
#
#        [[284, 106]],
#
#        [[285, 105]],
#
#        [[286, 106]],
#
#        [[286, 110]],
#
#        [[286, 105]]], dtype=int32), array([[[121, 105]],
#
#        [[124, 105]],
#
#        [[125, 106]],
#
#        [[125, 105]]], dtype=int32), array([[[521,  93]],
#
#        [[521,  94]],
#
#        [[520,  95]],
#
#        [[518,  95]],
#
#        [[521,  95]]], dtype=int32), array([[[490,  91]],
#
#        [[489,  92]],
#
#        [[488,  92]],
#
#        [[488,  93]]], dtype=int32), array([[[300,  94]],
#
#        [[299,  95]],
#
#        [[298,  95]],
#
#        [[300,  95]]], dtype=int32), array([[[199, 108]],
#
#        [[199, 109]],
#
#        [[200, 108]],
#
#        [[201, 109]],
#
#        [[203, 109]],
#
#        [[204, 110]],
#
#        [[207, 110]],
#
#        [[204, 110]],
#
#        [[203, 109]],
#
#        [[201, 109]],
#
#        [[200, 108]]], dtype=int32), array([[[519,  80]],
#
#        [[520,  81]],
#
#        [[520,  82]],
#
#        [[519,  83]],
#
#        [[520,  82]],
#
#        [[520,  80]]], dtype=int32), array([[[108,   0]],
#
#        [[108,   1]],
#
#        [[107,   2]],
#
#        [[108,   2]]], dtype=int32), array([[[ 51, 525]],
#
#        [[ 51, 526]],
#
#        [[ 50, 527]],
#
#        [[ 50, 530]],
#
#        [[ 50, 527]],
#
#        [[ 52, 525]],
#
#        [[ 53, 525]],
#
#        [[ 54, 526]],
#
#        [[ 54, 527]],
#
#        [[ 54, 525]]], dtype=int32), array([[[ 76, 427]],
#
#        [[ 82, 427]],
#
#        [[ 83, 428]],
#
#        [[ 82, 429]],
#
#        [[ 80, 429]],
#
#        [[ 79, 430]],
#
#        [[ 78, 429]],
#
#        [[ 77, 429]],
#
#        [[ 76, 430]],
#
#        [[ 76, 431]],
#
#        [[ 76, 430]],
#
#        [[ 77, 429]],
#
#        [[ 78, 429]],
#
#        [[ 79, 430]],
#
#        [[ 80, 429]],
#
#        [[ 83, 429]],
#
#        [[ 83, 427]]], dtype=int32), array([[[ 79, 423]],
#
#        [[ 79, 425]],
#
#        [[ 79, 424]],
#
#        [[ 80, 423]],
#
#        [[ 81, 424]],
#
#        [[ 81, 425]],
#
#        [[ 81, 423]]], dtype=int32), array([[[  6, 423]],
#
#        [[  5, 424]],
#
#        [[  0, 424]],
#
#        [[  5, 424]],
#
#        [[  6, 423]],
#
#        [[  9, 423]],
#
#        [[ 10, 424]],
#
#        [[ 10, 425]],
#
#        [[  9, 426]],
#
#        [[ 10, 425]],
#
#        [[ 10, 424]],
#
#        [[ 11, 423]]], dtype=int32), array([[[ 57, 427]],
#
#        [[ 56, 428]],
#
#        [[ 57, 428]],
#
#        [[ 58, 427]],
#
#        [[ 59, 427]]], dtype=int32), array([[[114, 402]],
#
#        [[113, 403]],
#
#        [[112, 403]],
#
#        [[112, 404]],
#
#        [[111, 405]],
#
#        [[111, 406]],
#
#        [[111, 405]],
#
#        [[113, 403]],
#
#        [[114, 403]]], dtype=int32), array([[[539, 381]],
#
#        [[539, 385]],
#
#        [[539, 383]],
#
#        [[540, 382]]], dtype=int32), array([[[546, 377]],
#
#        [[545, 378]],
#
#        [[539, 378]],
#
#        [[538, 379]],
#
#        [[523, 379]],
#
#        [[522, 380]],
#
#        [[521, 379]],
#
#        [[519, 379]],
#
#        [[518, 380]],
#
#        [[505, 380]],
#
#        [[504, 381]],
#
#        [[503, 381]],
#
#        [[502, 380]],
#
#        [[493, 380]],
#
#        [[492, 381]],
#
#        [[479, 381]],
#
#        [[478, 382]],
#
#        [[477, 381]],
#
#        [[469, 381]],
#
#        [[468, 382]],
#
#        [[466, 382]],
#
#        [[468, 382]],
#
#        [[469, 381]],
#
#        [[477, 381]],
#
#        [[478, 382]],
#
#        [[479, 381]],
#
#        [[492, 381]],
#
#        [[493, 380]],
#
#        [[502, 380]],
#
#        [[503, 381]],
#
#        [[504, 381]],
#
#        [[505, 380]],
#
#        [[518, 380]],
#
#        [[519, 379]],
#
#        [[521, 379]],
#
#        [[522, 380]],
#
#        [[523, 379]],
#
#        [[539, 379]],
#
#        [[540, 378]],
#
#        [[545, 378]],
#
#        [[546, 377]],
#
#        [[547, 378]],
#
#        [[547, 381]],
#
#        [[547, 378]]], dtype=int32), array([[[423, 365]],
#
#        [[422, 366]],
#
#        [[420, 366]],
#
#        [[419, 367]],
#
#        [[418, 367]],
#
#        [[417, 368]],
#
#        [[418, 368]],
#
#        [[420, 366]],
#
#        [[422, 366]],
#
#        [[423, 365]],
#
#        [[428, 365]]], dtype=int32), array([[[132, 332]],
#
#        [[134, 332]],
#
#        [[135, 333]],
#
#        [[135, 334]],
#
#        [[134, 335]],
#
#        [[133, 334]],
#
#        [[134, 335]],
#
#        [[135, 335]],
#
#        [[135, 332]]], dtype=int32), array([[[442, 325]],
#
#        [[444, 325]],
#
#        [[445, 326]],
#
#        [[444, 327]],
#
#        [[442, 327]],
#
#        [[441, 328]],
#
#        [[438, 328]],
#
#        [[441, 328]],
#
#        [[442, 327]],
#
#        [[445, 327]],
#
#        [[445, 325]]], dtype=int32), array([[[ 13, 321]],
#
#        [[ 14, 322]],
#
#        [[ 14, 325]],
#
#        [[ 14, 324]],
#
#        [[ 15, 323]]], dtype=int32), array([[[232, 317]],
#
#        [[232, 319]],
#
#        [[232, 318]],
#
#        [[233, 317]],
#
#        [[234, 317]],
#
#        [[235, 318]],
#
#        [[235, 320]],
#
#        [[235, 317]]], dtype=int32), array([[[339, 305]],
#
#        [[336, 308]],
#
#        [[338, 306]],
#
#        [[339, 306]],
#
#        [[340, 305]]], dtype=int32), array([[[243, 292]],
#
#        [[246, 292]],
#
#        [[247, 293]],
#
#        [[246, 294]],
#
#        [[245, 294]],
#
#        [[244, 295]],
#
#        [[245, 294]],
#
#        [[247, 294]],
#
#        [[247, 292]]], dtype=int32), array([[[157, 289]],
#
#        [[157, 293]],
#
#        [[156, 294]],
#
#        [[154, 294]],
#
#        [[153, 295]],
#
#        [[154, 294]],
#
#        [[157, 294]],
#
#        [[157, 290]],
#
#        [[158, 289]]], dtype=int32), array([[[119, 287]],
#
#        [[118, 288]],
#
#        [[119, 288]],
#
#        [[120, 287]],
#
#        [[121, 287]]], dtype=int32), array([[[ 52, 284]],
#
#        [[ 51, 285]],
#
#        [[ 52, 286]],
#
#        [[ 52, 288]]], dtype=int32), array([[[240, 280]],
#
#        [[240, 282]],
#
#        [[239, 283]],
#
#        [[238, 282]],
#
#        [[236, 282]],
#
#        [[235, 281]],
#
#        [[232, 281]],
#
#        [[235, 281]],
#
#        [[236, 282]],
#
#        [[237, 282]],
#
#        [[238, 283]],
#
#        [[239, 283]],
#
#        [[240, 282]]], dtype=int32), array([[[459, 269]],
#
#        [[460, 270]],
#
#        [[461, 269]]], dtype=int32), array([[[487, 257]],
#
#        [[486, 258]],
#
#        [[484, 258]],
#
#        [[483, 259]],
#
#        [[484, 259]],
#
#        [[485, 260]],
#
#        [[484, 259]],
#
#        [[485, 258]],
#
#        [[486, 258]],
#
#        [[487, 257]],
#
#        [[489, 257]]], dtype=int32), array([[[191, 233]],
#
#        [[192, 234]],
#
#        [[195, 234]],
#
#        [[196, 235]],
#
#        [[201, 235]],
#
#        [[197, 235]],
#
#        [[196, 234]],
#
#        [[192, 234]]], dtype=int32), array([[[190, 231]],
#
#        [[194, 231]],
#
#        [[195, 232]],
#
#        [[198, 232]],
#
#        [[199, 233]],
#
#        [[200, 233]],
#
#        [[199, 232]],
#
#        [[195, 232]],
#
#        [[194, 231]]], dtype=int32), array([[[356, 209]],
#
#        [[356, 211]],
#
#        [[355, 212]],
#
#        [[355, 213]],
#
#        [[356, 214]],
#
#        [[356, 218]],
#
#        [[357, 217]],
#
#        [[359, 217]],
#
#        [[357, 217]],
#
#        [[356, 216]],
#
#        [[356, 214]],
#
#        [[355, 213]],
#
#        [[355, 212]],
#
#        [[356, 211]]], dtype=int32), array([[[367, 194]],
#
#        [[367, 197]],
#
#        [[368, 197]],
#
#        [[369, 196]],
#
#        [[371, 196]],
#
#        [[369, 196]],
#
#        [[368, 197]],
#
#        [[367, 196]],
#
#        [[367, 195]],
#
#        [[368, 194]],
#
#        [[371, 194]]], dtype=int32), array([[[283, 194]],
#
#        [[288, 194]],
#
#        [[289, 195]],
#
#        [[290, 195]],
#
#        [[289, 194]]], dtype=int32), array([[[197, 169]],
#
#        [[197, 170]],
#
#        [[196, 171]],
#
#        [[200, 171]],
#
#        [[198, 171]],
#
#        [[197, 170]]], dtype=int32), array([[[223, 163]],
#
#        [[222, 164]],
#
#        [[223, 164]],
#
#        [[224, 163]]], dtype=int32), array([[[462, 160]],
#
#        [[462, 163]],
#
#        [[462, 161]],
#
#        [[463, 160]],
#
#        [[464, 161]],
#
#        [[464, 162]],
#
#        [[464, 160]]], dtype=int32), array([[[199, 156]],
#
#        [[199, 157]],
#
#        [[200, 158]],
#
#        [[200, 161]],
#
#        [[200, 157]]], dtype=int32), array([[[448, 152]],
#
#        [[447, 153]],
#
#        [[446, 153]],
#
#        [[449, 153]],
#
#        [[450, 152]],
#
#        [[453, 152]],
#
#        [[450, 152]],
#
#        [[449, 153]]], dtype=int32), array([[[474, 148]],
#
#        [[474, 151]],
#
#        [[474, 150]],
#
#        [[475, 149]],
#
#        [[477, 149]],
#
#        [[475, 149]]], dtype=int32), array([[[471, 148]],
#
#        [[471, 149]],
#
#        [[472, 150]],
#
#        [[472, 151]],
#
#        [[472, 149]]], dtype=int32), array([[[  3, 145]],
#
#        [[  2, 146]],
#
#        [[  0, 146]],
#
#        [[  2, 146]],
#
#        [[  3, 145]],
#
#        [[  5, 145]],
#
#        [[  6, 146]],
#
#        [[  8, 146]],
#
#        [[  9, 145]],
#
#        [[ 14, 145]],
#
#        [[  8, 145]],
#
#        [[  7, 146]],
#
#        [[  6, 146]],
#
#        [[  5, 145]]], dtype=int32), array([[[553, 141]],
#
#        [[551, 143]],
#
#        [[551, 144]],
#
#        [[552, 143]],
#
#        [[552, 142]],
#
#        [[553, 141]],
#
#        [[554, 141]]], dtype=int32), array([[[270, 192]],
#
#        [[269, 193]],
#
#        [[264, 193]],
#
#        [[270, 193]],
#
#        [[271, 192]]], dtype=int32), array([[[275, 190]],
#
#        [[275, 192]],
#
#        [[276, 193]],
#
#        [[276, 192]],
#
#        [[277, 191]],
#
#        [[277, 190]],
#
#        [[277, 191]],
#
#        [[276, 192]],
#
#        [[275, 191]]], dtype=int32), array([[[389, 125]],
#
#        [[389, 128]],
#
#        [[389, 126]],
#
#        [[390, 125]],
#
#        [[391, 126]],
#
#        [[391, 128]],
#
#        [[391, 125]]], dtype=int32), array([[[548, 121]],
#
#        [[548, 122]],
#
#        [[549, 123]],
#
#        [[549, 126]],
#
#        [[549, 122]]], dtype=int32), array([[[508, 115]],
#
#        [[507, 116]],
#
#        [[494, 116]],
#
#        [[509, 116]]], dtype=int32), array([[[437,  98]],
#
#        [[437,  99]],
#
#        [[438, 100]],
#
#        [[438,  99]]], dtype=int32), array([[[236,  96]],
#
#        [[237,  97]],
#
#        [[238,  97]],
#
#        [[237,  96]]], dtype=int32), array([[[580,  95]],
#
#        [[580,  96]],
#
#        [[581,  97]],
#
#        [[581, 101]],
#
#        [[582, 102]],
#
#        [[582, 103]],
#
#        [[582, 102]],
#
#        [[581, 101]],
#
#        [[581,  96]]], dtype=int32), array([[[345,  91]],
#
#        [[345,  93]],
#
#        [[346,  92]]], dtype=int32), array([[[522,  90]],
#
#        [[522,  91]],
#
#        [[523,  92]],
#
#        [[523,  97]],
#
#        [[523,  91]]], dtype=int32), array([[[45, 90]],
#
#        [[45, 91]],
#
#        [[44, 92]],
#
#        [[46, 92]],
#
#        [[45, 91]]], dtype=int32), array([[[171,  99]],
#
#        [[170, 100]],
#
#        [[167, 100]],
#
#        [[167, 101]],
#
#        [[166, 102]],
#
#        [[166, 104]],
#
#        [[165, 105]],
#
#        [[165, 106]],
#
#        [[172, 106]],
#
#        [[173, 105]],
#
#        [[178, 105]],
#
#        [[179, 104]],
#
#        [[178, 105]],
#
#        [[173, 105]],
#
#        [[172, 106]],
#
#        [[166, 106]],
#
#        [[165, 105]],
#
#        [[166, 104]],
#
#        [[166, 102]],
#
#        [[168, 100]],
#
#        [[170, 100]]], dtype=int32), array([[[262,  82]],
#
#        [[265,  82]],
#
#        [[266,  83]],
#
#        [[269,  83]],
#
#        [[267,  83]],
#
#        [[266,  82]]], dtype=int32), array([[[204, 105]],
#
#        [[204, 107]],
#
#        [[206, 107]],
#
#        [[207, 108]],
#
#        [[207, 107]],
#
#        [[205, 107]],
#
#        [[204, 106]]], dtype=int32), array([[[30, 71]],
#
#        [[29, 72]],
#
#        [[27, 72]],
#
#        [[26, 73]],
#
#        [[23, 73]],
#
#        [[22, 74]],
#
#        [[21, 73]],
#
#        [[21, 74]],
#
#        [[22, 74]],
#
#        [[23, 73]],
#
#        [[26, 73]],
#
#        [[27, 72]],
#
#        [[30, 72]],
#
#        [[31, 73]],
#
#        [[34, 73]],
#
#        [[31, 73]],
#
#        [[30, 72]]], dtype=int32), array([[[531,  68]],
#
#        [[531,  69]],
#
#        [[532,  70]],
#
#        [[532,  72]],
#
#        [[532,  69]]], dtype=int32), array([[[507,  58]],
#
#        [[506,  59]],
#
#        [[506,  60]],
#
#        [[507,  61]],
#
#        [[507,  60]],
#
#        [[506,  59]]], dtype=int32), array([[[ 0, 53]],
#
#        [[ 2, 53]],
#
#        [[ 3, 54]],
#
#        [[10, 54]],
#
#        [[ 4, 54]],
#
#        [[ 3, 53]]], dtype=int32), array([[[530,  22]],
#
#        [[530,  24]],
#
#        [[531,  25]],
#
#        [[531,  30]],
#
#        [[532,  31]],
#
#        [[532,  38]],
#
#        [[533,  39]],
#
#        [[533,  40]],
#
#        [[533,  38]],
#
#        [[532,  37]],
#
#        [[532,  31]],
#
#        [[531,  30]],
#
#        [[531,  25]],
#
#        [[530,  24]]], dtype=int32), array([[[76, 22]],
#
#        [[75, 23]],
#
#        [[77, 23]]], dtype=int32), array([[[ 58, 492]],
#
#        [[ 58, 494]],
#
#        [[ 59, 495]],
#
#        [[ 59, 496]],
#
#        [[ 60, 497]],
#
#        [[ 60, 496]],
#
#        [[ 58, 494]],
#
#        [[ 58, 493]],
#
#        [[ 59, 492]],
#
#        [[ 60, 492]]], dtype=int32), array([[[ 16, 463]],
#
#        [[ 16, 464]],
#
#        [[ 17, 465]],
#
#        [[ 18, 465]]], dtype=int32), array([[[  2, 415]],
#
#        [[  1, 416]],
#
#        [[  1, 418]],
#
#        [[  1, 417]],
#
#        [[  3, 415]],
#
#        [[  6, 415]]], dtype=int32), array([[[568, 389]],
#
#        [[568, 392]],
#
#        [[572, 392]],
#
#        [[569, 392]],
#
#        [[568, 391]],
#
#        [[569, 390]]], dtype=int32), array([[[443, 370]],
#
#        [[442, 371]],
#
#        [[438, 371]],
#
#        [[437, 372]],
#
#        [[435, 372]],
#
#        [[434, 373]],
#
#        [[433, 373]],
#
#        [[434, 373]],
#
#        [[435, 372]],
#
#        [[438, 372]],
#
#        [[439, 371]],
#
#        [[443, 371]]], dtype=int32), array([[[ 66, 359]],
#
#        [[ 66, 360]],
#
#        [[ 67, 361]],
#
#        [[ 70, 361]],
#
#        [[ 71, 362]],
#
#        [[ 73, 362]],
#
#        [[ 72, 362]],
#
#        [[ 71, 361]],
#
#        [[ 67, 361]],
#
#        [[ 66, 360]],
#
#        [[ 67, 359]],
#
#        [[ 71, 359]]], dtype=int32), array([[[286, 341]],
#
#        [[287, 341]],
#
#        [[289, 343]],
#
#        [[289, 342]],
#
#        [[288, 341]]], dtype=int32), array([[[506, 327]],
#
#        [[505, 328]],
#
#        [[506, 327]],
#
#        [[507, 327]],
#
#        [[508, 328]],
#
#        [[508, 332]],
#
#        [[508, 330]],
#
#        [[509, 329]],
#
#        [[508, 328]],
#
#        [[508, 327]]], dtype=int32), array([[[251, 322]],
#
#        [[252, 322]],
#
#        [[253, 323]],
#
#        [[252, 324]],
#
#        [[250, 324]],
#
#        [[254, 324]],
#
#        [[253, 323]],
#
#        [[253, 322]]], dtype=int32), array([[[353, 314]],
#
#        [[354, 315]],
#
#        [[354, 316]],
#
#        [[357, 316]],
#
#        [[355, 316]],
#
#        [[354, 315]],
#
#        [[355, 314]],
#
#        [[360, 314]]], dtype=int32), array([[[346, 312]],
#
#        [[347, 313]],
#
#        [[347, 314]],
#
#        [[348, 314]],
#
#        [[347, 313]],
#
#        [[348, 312]]], dtype=int32), array([[[125, 312]],
#
#        [[126, 312]],
#
#        [[127, 313]],
#
#        [[130, 313]],
#
#        [[131, 314]],
#
#        [[130, 315]],
#
#        [[124, 315]],
#
#        [[123, 316]],
#
#        [[118, 316]],
#
#        [[117, 315]],
#
#        [[119, 313]],
#
#        [[120, 314]],
#
#        [[122, 314]],
#
#        [[120, 314]],
#
#        [[119, 313]],
#
#        [[117, 315]],
#
#        [[117, 316]],
#
#        [[123, 316]],
#
#        [[124, 315]],
#
#        [[131, 315]],
#
#        [[132, 316]],
#
#        [[131, 315]],
#
#        [[131, 313]],
#
#        [[127, 313]],
#
#        [[126, 312]]], dtype=int32), array([[[580, 279]],
#
#        [[580, 282]],
#
#        [[581, 283]],
#
#        [[581, 287]],
#
#        [[582, 288]],
#
#        [[583, 288]],
#
#        [[581, 286]],
#
#        [[581, 283]],
#
#        [[580, 282]]], dtype=int32), array([[[566, 255]],
#
#        [[571, 255]],
#
#        [[573, 257]],
#
#        [[572, 258]],
#
#        [[571, 258]],
#
#        [[570, 259]],
#
#        [[571, 259]],
#
#        [[573, 257]],
#
#        [[572, 256]],
#
#        [[572, 255]]], dtype=int32), array([[[293, 232]],
#
#        [[293, 234]],
#
#        [[294, 233]],
#
#        [[295, 234]],
#
#        [[295, 233]],
#
#        [[294, 233]]], dtype=int32), array([[[267, 232]],
#
#        [[267, 234]],
#
#        [[268, 235]],
#
#        [[268, 234]],
#
#        [[267, 233]],
#
#        [[268, 232]]], dtype=int32), array([[[459, 231]],
#
#        [[460, 232]],
#
#        [[460, 233]],
#
#        [[459, 234]],
#
#        [[459, 236]],
#
#        [[459, 235]],
#
#        [[460, 234]],
#
#        [[460, 231]]], dtype=int32), array([[[356, 220]],
#
#        [[356, 233]],
#
#        [[357, 234]],
#
#        [[359, 234]],
#
#        [[358, 234]],
#
#        [[356, 232]]], dtype=int32), array([[[435, 204]],
#
#        [[436, 205]],
#
#        [[435, 206]],
#
#        [[435, 208]],
#
#        [[435, 207]],
#
#        [[436, 206]],
#
#        [[436, 204]]], dtype=int32), array([[[448, 202]],
#
#        [[449, 202]],
#
#        [[451, 204]],
#
#        [[451, 205]],
#
#        [[451, 203]],
#
#        [[450, 202]]], dtype=int32), array([[[527, 199]],
#
#        [[527, 200]],
#
#        [[526, 201]],
#
#        [[526, 223]],
#
#        [[527, 224]],
#
#        [[527, 238]],
#
#        [[528, 239]],
#
#        [[527, 240]],
#
#        [[527, 245]],
#
#        [[528, 246]],
#
#        [[527, 247]],
#
#        [[528, 246]],
#
#        [[529, 247]],
#
#        [[531, 247]],
#
#        [[530, 247]],
#
#        [[529, 246]],
#
#        [[528, 246]],
#
#        [[527, 245]],
#
#        [[527, 240]],
#
#        [[528, 239]],
#
#        [[527, 238]],
#
#        [[527, 224]],
#
#        [[526, 223]],
#
#        [[526, 201]],
#
#        [[528, 199]]], dtype=int32), array([[[519, 172]],
#
#        [[517, 174]],
#
#        [[513, 174]],
#
#        [[518, 174]],
#
#        [[519, 173]]], dtype=int32), array([[[ 80, 172]],
#
#        [[ 80, 176]],
#
#        [[ 79, 177]],
#
#        [[ 78, 177]],
#
#        [[ 77, 178]],
#
#        [[ 78, 178]],
#
#        [[ 79, 177]],
#
#        [[ 80, 177]]], dtype=int32), array([[[264, 157]],
#
#        [[264, 159]],
#
#        [[263, 160]],
#
#        [[262, 160]],
#
#        [[263, 160]],
#
#        [[264, 159]],
#
#        [[265, 160]],
#
#        [[265, 161]],
#
#        [[265, 160]],
#
#        [[264, 159]],
#
#        [[264, 158]],
#
#        [[265, 157]],
#
#        [[267, 157]],
#
#        [[268, 158]],
#
#        [[270, 158]],
#
#        [[269, 158]],
#
#        [[268, 157]]], dtype=int32), array([[[525, 154]],
#
#        [[525, 171]],
#
#        [[526, 172]],
#
#        [[526, 174]],
#
#        [[541, 174]],
#
#        [[542, 175]],
#
#        [[543, 175]],
#
#        [[544, 174]],
#
#        [[575, 174]],
#
#        [[576, 173]],
#
#        [[577, 173]],
#
#        [[575, 173]],
#
#        [[574, 174]],
#
#        [[544, 174]],
#
#        [[543, 175]],
#
#        [[542, 175]],
#
#        [[541, 174]],
#
#        [[527, 174]],
#
#        [[526, 173]],
#
#        [[526, 172]],
#
#        [[527, 171]],
#
#        [[544, 171]],
#
#        [[545, 172]],
#
#        [[546, 171]],
#
#        [[547, 172]],
#
#        [[549, 172]],
#
#        [[550, 171]],
#
#        [[555, 171]],
#
#        [[556, 172]],
#
#        [[559, 172]],
#
#        [[560, 171]],
#
#        [[576, 171]],
#
#        [[560, 171]],
#
#        [[559, 172]],
#
#        [[556, 172]],
#
#        [[555, 171]],
#
#        [[550, 171]],
#
#        [[549, 172]],
#
#        [[547, 172]],
#
#        [[546, 171]],
#
#        [[545, 172]],
#
#        [[544, 171]],
#
#        [[527, 171]],
#
#        [[526, 172]],
#
#        [[525, 171]]], dtype=int32), array([[[397, 151]],
#
#        [[397, 153]],
#
#        [[396, 154]],
#
#        [[396, 155]],
#
#        [[397, 156]],
#
#        [[397, 159]],
#
#        [[397, 155]],
#
#        [[396, 154]],
#
#        [[397, 153]],
#
#        [[397, 152]],
#
#        [[398, 151]],
#
#        [[399, 152]],
#
#        [[399, 158]],
#
#        [[399, 152]],
#
#        [[398, 151]]], dtype=int32), array([[[434, 142]],
#
#        [[434, 144]],
#
#        [[433, 145]],
#
#        [[431, 145]],
#
#        [[439, 145]],
#
#        [[440, 144]],
#
#        [[441, 144]],
#
#        [[440, 144]],
#
#        [[439, 145]],
#
#        [[435, 145]],
#
#        [[434, 144]],
#
#        [[434, 143]],
#
#        [[435, 142]],
#
#        [[442, 142]]], dtype=int32), array([[[252, 186]],
#
#        [[252, 187]],
#
#        [[249, 190]],
#
#        [[245, 190]],
#
#        [[250, 190]],
#
#        [[251, 189]],
#
#        [[251, 188]],
#
#        [[252, 187]]], dtype=int32), array([[[427, 132]],
#
#        [[427, 134]],
#
#        [[428, 134]],
#
#        [[429, 135]],
#
#        [[429, 136]],
#
#        [[429, 135]],
#
#        [[430, 134]],
#
#        [[428, 134]],
#
#        [[427, 133]]], dtype=int32), array([[[472, 120]],
#
#        [[471, 121]],
#
#        [[472, 121]],
#
#        [[473, 120]],
#
#        [[480, 120]],
#
#        [[482, 122]],
#
#        [[482, 126]],
#
#        [[482, 122]],
#
#        [[481, 121]],
#
#        [[481, 120]]], dtype=int32), array([[[ 48, 119]],
#
#        [[ 48, 120]],
#
#        [[ 47, 121]],
#
#        [[ 40, 121]],
#
#        [[ 47, 121]],
#
#        [[ 48, 122]],
#
#        [[ 48, 125]],
#
#        [[ 49, 126]],
#
#        [[ 49, 139]],
#
#        [[ 47, 141]],
#
#        [[ 31, 141]],
#
#        [[ 30, 142]],
#
#        [[  9, 142]],
#
#        [[  8, 143]],
#
#        [[  0, 143]],
#
#        [[  8, 143]],
#
#        [[  9, 142]],
#
#        [[ 30, 142]],
#
#        [[ 31, 141]],
#
#        [[ 48, 141]],
#
#        [[ 49, 142]],
#
#        [[ 48, 141]],
#
#        [[ 48, 140]],
#
#        [[ 49, 139]],
#
#        [[ 49, 126]],
#
#        [[ 48, 125]]], dtype=int32), array([[[ 11, 119]],
#
#        [[ 10, 120]],
#
#        [[ 10, 121]],
#
#        [[ 11, 122]],
#
#        [[ 21, 122]],
#
#        [[ 22, 123]],
#
#        [[ 23, 122]],
#
#        [[ 25, 122]],
#
#        [[ 26, 121]],
#
#        [[ 30, 121]],
#
#        [[ 31, 120]],
#
#        [[ 32, 120]],
#
#        [[ 31, 120]],
#
#        [[ 30, 121]],
#
#        [[ 26, 121]],
#
#        [[ 25, 122]],
#
#        [[ 23, 122]],
#
#        [[ 22, 123]],
#
#        [[ 21, 122]],
#
#        [[ 11, 122]],
#
#        [[ 10, 121]],
#
#        [[ 12, 119]],
#
#        [[ 13, 119]]], dtype=int32), array([[[524, 109]],
#
#        [[524, 122]],
#
#        [[525, 123]],
#
#        [[525, 125]],
#
#        [[524, 126]],
#
#        [[525, 126]],
#
#        [[526, 127]],
#
#        [[526, 126]],
#
#        [[525, 125]],
#
#        [[525, 123]],
#
#        [[524, 122]]], dtype=int32), array([[[405, 109]],
#
#        [[407, 109]],
#
#        [[409, 111]],
#
#        [[409, 110]],
#
#        [[408, 109]]], dtype=int32), array([[[127, 106]],
#
#        [[129, 108]],
#
#        [[129, 109]],
#
#        [[129, 107]],
#
#        [[128, 106]]], dtype=int32), array([[[114, 104]],
#
#        [[114, 106]],
#
#        [[113, 107]],
#
#        [[111, 107]],
#
#        [[112, 107]],
#
#        [[113, 108]],
#
#        [[113, 109]],
#
#        [[114, 110]],
#
#        [[114, 109]],
#
#        [[113, 108]],
#
#        [[113, 107]],
#
#        [[114, 106]]], dtype=int32), array([[[331, 101]],
#
#        [[331, 103]],
#
#        [[330, 104]],
#
#        [[333, 104]],
#
#        [[332, 104]],
#
#        [[331, 103]],
#
#        [[331, 102]],
#
#        [[332, 101]],
#
#        [[334, 101]]], dtype=int32), array([[[320, 101]],
#
#        [[319, 102]],
#
#        [[319, 103]],
#
#        [[318, 104]],
#
#        [[321, 101]],
#
#        [[322, 102]],
#
#        [[322, 103]],
#
#        [[322, 102]],
#
#        [[321, 101]]], dtype=int32), array([[[100, 100]],
#
#        [[102, 100]],
#
#        [[103, 101]],
#
#        [[103, 102]],
#
#        [[102, 103]],
#
#        [[101, 103]],
#
#        [[100, 102]],
#
#        [[100, 103]],
#
#        [[103, 103]],
#
#        [[103, 100]]], dtype=int32), array([[[ 43, 100]],
#
#        [[ 45, 102]],
#
#        [[ 45, 103]],
#
#        [[ 45, 101]],
#
#        [[ 44, 100]]], dtype=int32), array([[[472,  89]],
#
#        [[471,  90]],
#
#        [[470,  90]],
#
#        [[471,  90]],
#
#        [[472,  89]],
#
#        [[479,  89]],
#
#        [[481,  91]],
#
#        [[481,  90]],
#
#        [[480,  89]]], dtype=int32), array([[[118, 134]],
#
#        [[118, 136]],
#
#        [[121, 136]],
#
#        [[121, 135]],
#
#        [[120, 136]],
#
#        [[119, 136]],
#
#        [[118, 135]],
#
#        [[119, 134]]], dtype=int32), array([[[478,  18]],
#
#        [[478,  20]],
#
#        [[477,  21]],
#
#        [[476,  20]],
#
#        [[477,  21]],
#
#        [[478,  21]],
#
#        [[479,  20]],
#
#        [[478,  19]]], dtype=int32), array([[[581,  10]],
#
#        [[580,  11]],
#
#        [[580,  12]],
#
#        [[582,  10]]], dtype=int32), array([[[213, 478]],
#
#        [[213, 479]],
#
#        [[212, 480]],
#
#        [[213, 481]],
#
#        [[213, 483]],
#
#        [[212, 484]],
#
#        [[213, 485]],
#
#        [[213, 488]]], dtype=int32), array([[[ 70, 455]],
#
#        [[ 71, 454]],
#
#        [[ 72, 455]],
#
#        [[ 71, 456]]], dtype=int32), array([[[262, 376]],
#
#        [[263, 375]],
#
#        [[264, 376]],
#
#        [[263, 377]]], dtype=int32), array([[[356, 371]],
#
#        [[356, 374]],
#
#        [[360, 374]],
#
#        [[359, 373]],
#
#        [[358, 374]],
#
#        [[357, 374]],
#
#        [[356, 373]],
#
#        [[356, 372]],
#
#        [[357, 371]],
#
#        [[360, 371]]], dtype=int32), array([[[430, 349]],
#
#        [[429, 350]],
#
#        [[433, 350]],
#
#        [[434, 349]],
#
#        [[433, 349]],
#
#        [[432, 350]],
#
#        [[431, 350]]], dtype=int32), array([[[277, 348]],
#
#        [[277, 350]],
#
#        [[275, 352]],
#
#        [[276, 352]],
#
#        [[277, 351]],
#
#        [[278, 351]],
#
#        [[277, 350]]], dtype=int32), array([[[104, 334]],
#
#        [[103, 335]],
#
#        [[101, 335]],
#
#        [[101, 338]],
#
#        [[ 99, 340]],
#
#        [[100, 339]],
#
#        [[101, 339]],
#
#        [[101, 336]],
#
#        [[102, 335]],
#
#        [[105, 335]]], dtype=int32), array([[[292, 331]],
#
#        [[293, 330]],
#
#        [[294, 331]],
#
#        [[293, 332]]], dtype=int32), array([[[260, 314]],
#
#        [[261, 313]],
#
#        [[262, 314]],
#
#        [[261, 315]]], dtype=int32), array([[[251, 312]],
#
#        [[254, 312]],
#
#        [[255, 313]],
#
#        [[253, 315]],
#
#        [[252, 314]],
#
#        [[253, 315]],
#
#        [[254, 315]],
#
#        [[255, 314]],
#
#        [[255, 312]]], dtype=int32), array([[[295, 296]],
#
#        [[295, 298]],
#
#        [[297, 298]],
#
#        [[298, 299]],
#
#        [[299, 298]],
#
#        [[296, 298]],
#
#        [[295, 297]],
#
#        [[296, 296]]], dtype=int32), array([[[213, 292]],
#
#        [[213, 300]],
#
#        [[214, 300]],
#
#        [[213, 299]],
#
#        [[213, 294]],
#
#        [[214, 293]],
#
#        [[214, 292]]], dtype=int32), array([[[122, 289]],
#
#        [[121, 290]],
#
#        [[122, 289]],
#
#        [[124, 291]],
#
#        [[124, 292]],
#
#        [[125, 292]],
#
#        [[124, 291]],
#
#        [[124, 290]],
#
#        [[123, 289]]], dtype=int32), array([[[ 34, 287]],
#
#        [[ 35, 286]],
#
#        [[ 36, 287]],
#
#        [[ 35, 288]]], dtype=int32), array([[[161, 330]],
#
#        [[162, 329]],
#
#        [[163, 330]],
#
#        [[162, 331]]], dtype=int32), array([[[476, 288]],
#
#        [[477, 287]],
#
#        [[478, 288]],
#
#        [[477, 289]]], dtype=int32), array([[[566, 252]],
#
#        [[577, 252]],
#
#        [[578, 253]],
#
#        [[578, 254]],
#
#        [[577, 255]],
#
#        [[575, 255]],
#
#        [[578, 255]],
#
#        [[578, 254]],
#
#        [[579, 253]],
#
#        [[578, 252]]], dtype=int32), array([[[264, 231]],
#
#        [[262, 233]],
#
#        [[261, 233]],
#
#        [[263, 233]],
#
#        [[265, 231]]], dtype=int32), array([[[ 90, 228]],
#
#        [[ 89, 229]],
#
#        [[ 89, 241]],
#
#        [[ 88, 242]],
#
#        [[ 86, 242]],
#
#        [[ 85, 243]],
#
#        [[ 80, 243]],
#
#        [[ 85, 243]],
#
#        [[ 86, 242]],
#
#        [[ 89, 242]],
#
#        [[ 89, 230]],
#
#        [[ 91, 228]],
#
#        [[ 95, 228]]], dtype=int32), array([[[ 49, 226]],
#
#        [[ 49, 227]],
#
#        [[ 48, 228]],
#
#        [[ 46, 228]],
#
#        [[ 45, 227]],
#
#        [[ 45, 228]],
#
#        [[ 44, 229]],
#
#        [[ 40, 229]],
#
#        [[ 39, 228]],
#
#        [[ 37, 228]],
#
#        [[ 36, 229]],
#
#        [[ 29, 229]],
#
#        [[ 37, 229]],
#
#        [[ 38, 228]],
#
#        [[ 39, 228]],
#
#        [[ 40, 229]],
#
#        [[ 44, 229]],
#
#        [[ 45, 228]],
#
#        [[ 49, 228]]], dtype=int32), array([[[276, 210]],
#
#        [[275, 211]],
#
#        [[274, 211]],
#
#        [[274, 212]],
#
#        [[276, 210]],
#
#        [[277, 211]],
#
#        [[278, 211]],
#
#        [[280, 213]],
#
#        [[280, 212]],
#
#        [[279, 211]],
#
#        [[277, 211]]], dtype=int32), array([[[453, 202]],
#
#        [[453, 203]],
#
#        [[454, 204]],
#
#        [[453, 205]],
#
#        [[454, 206]],
#
#        [[454, 203]]], dtype=int32), array([[[575, 193]],
#
#        [[574, 194]],
#
#        [[530, 194]],
#
#        [[530, 195]],
#
#        [[531, 194]],
#
#        [[574, 194]],
#
#        [[575, 193]],
#
#        [[576, 193]],
#
#        [[577, 194]],
#
#        [[578, 194]],
#
#        [[581, 197]],
#
#        [[581, 198]],
#
#        [[581, 197]],
#
#        [[580, 196]],
#
#        [[580, 195]],
#
#        [[579, 194]],
#
#        [[577, 194]],
#
#        [[576, 193]]], dtype=int32), array([[[284, 181]],
#
#        [[283, 182]],
#
#        [[282, 182]],
#
#        [[284, 182]],
#
#        [[286, 184]],
#
#        [[286, 185]],
#
#        [[296, 185]],
#
#        [[297, 186]],
#
#        [[301, 186]],
#
#        [[302, 185]],
#
#        [[305, 185]],
#
#        [[307, 187]],
#
#        [[307, 190]],
#
#        [[307, 186]],
#
#        [[306, 186]],
#
#        [[305, 185]],
#
#        [[305, 184]],
#
#        [[304, 185]],
#
#        [[302, 185]],
#
#        [[301, 186]],
#
#        [[297, 186]],
#
#        [[296, 185]],
#
#        [[287, 185]],
#
#        [[286, 184]],
#
#        [[287, 183]],
#
#        [[288, 183]],
#
#        [[289, 182]],
#
#        [[295, 182]],
#
#        [[296, 183]],
#
#        [[301, 183]],
#
#        [[302, 182]],
#
#        [[306, 182]],
#
#        [[302, 182]],
#
#        [[301, 183]],
#
#        [[296, 183]],
#
#        [[295, 182]],
#
#        [[289, 182]],
#
#        [[288, 183]],
#
#        [[287, 183]],
#
#        [[286, 184]],
#
#        [[284, 182]]], dtype=int32), array([[[ 58, 147]],
#
#        [[ 59, 147]],
#
#        [[ 61, 149]],
#
#        [[ 62, 149]],
#
#        [[ 60, 147]]], dtype=int32), array([[[244, 180]],
#
#        [[245, 181]],
#
#        [[248, 181]],
#
#        [[249, 182]],
#
#        [[253, 182]],
#
#        [[254, 181]],
#
#        [[255, 181]],
#
#        [[253, 181]],
#
#        [[252, 182]],
#
#        [[250, 182]],
#
#        [[249, 181]],
#
#        [[245, 181]]], dtype=int32), array([[[ 46, 134]],
#
#        [[ 46, 137]],
#
#        [[ 45, 138]],
#
#        [[ 44, 138]],
#
#        [[ 45, 138]],
#
#        [[ 46, 139]],
#
#        [[ 46, 138]],
#
#        [[ 47, 137]],
#
#        [[ 46, 136]]], dtype=int32), array([[[256, 126]],
#
#        [[255, 127]],
#
#        [[255, 132]],
#
#        [[254, 133]],
#
#        [[253, 132]],
#
#        [[253, 131]],
#
#        [[252, 130]],
#
#        [[252, 128]],
#
#        [[252, 131]],
#
#        [[253, 132]],
#
#        [[253, 133]],
#
#        [[255, 133]],
#
#        [[255, 127]]], dtype=int32), array([[[377, 185]],
#
#        [[378, 184]],
#
#        [[379, 185]],
#
#        [[378, 186]]], dtype=int32), array([[[358, 133]],
#
#        [[358, 136]],
#
#        [[359, 137]],
#
#        [[359, 146]],
#
#        [[359, 138]],
#
#        [[360, 137]],
#
#        [[358, 135]]], dtype=int32), array([[[355, 128]],
#
#        [[354, 129]],
#
#        [[356, 131]],
#
#        [[356, 132]],
#
#        [[356, 130]],
#
#        [[355, 129]]], dtype=int32), array([[[546, 120]],
#
#        [[546, 128]],
#
#        [[547, 129]],
#
#        [[547, 128]],
#
#        [[546, 127]],
#
#        [[546, 126]],
#
# ...
#
#        [[159, 325]],
#
#        [[157, 325]],
#
#        [[158, 325]],
#
#        [[160, 327]],
#
#        [[158, 329]],
#
#        [[156, 327]],
#
#        [[158, 329]],
#
#        [[158, 331]],
#
#        [[159, 332]],
#
#        [[159, 338]],
#
#        [[164, 338]],
#
#        [[165, 337]],
#
#        [[166, 337]],
#
#        [[166, 330]],
#
#        [[168, 328]],
#
#        [[168, 326]],
#
#        [[164, 326]],
#
#        [[163, 327]],
#
#        [[162, 327]],
#
#        [[161, 326]],
#
#        [[160, 327]],
#
#        [[159, 326]],
#
#        [[159, 325]],
#
#        [[160, 324]],
#
#        [[160, 322]],
#
#        [[155, 322]],
#
#        [[154, 321]],
#
#        [[154, 304]],
#
#        [[155, 303]],
#
#        [[159, 303]],
#
#        [[160, 304]],
#
#        [[160, 305]],
#
#        [[161, 304]],
#
#        [[165, 304]],
#
#        [[167, 306]],
#
#        [[166, 307]],
#
#        [[165, 307]],
#
#        [[164, 308]],
#
#        [[163, 307]],
#
#        [[159, 307]],
#
#        [[158, 306]],
#
#        [[156, 306]],
#
#        [[158, 306]],
#
#        [[159, 307]],
#
#        [[163, 307]],
#
#        [[164, 308]],
#
#        [[165, 307]],
#
#        [[166, 307]],
#
#        [[168, 309]],
#
#        [[168, 313]],
#
#        [[166, 315]],
#
#        [[162, 315]],
#
#        [[161, 316]],
#
#        [[160, 316]],
#
#        [[161, 316]],
#
#        [[162, 315]],
#
#        [[166, 315]],
#
#        [[167, 316]],
#
#        [[167, 317]],
#
#        [[166, 318]],
#
#        [[160, 318]],
#
#        [[166, 318]],
#
#        [[167, 317]],
#
#        [[167, 314]],
#
#        [[168, 313]],
#
#        [[168, 308]],
#
#        [[167, 308]],
#
#        [[166, 307]],
#
#        [[167, 306]],
#
#        [[166, 305]],
#
#        [[166, 304]],
#
#        [[167, 303]],
#
#        [[167, 299]],
#
#        [[166, 298]],
#
#        [[168, 296]],
#
#        [[170, 296]],
#
#        [[171, 295]],
#
#        [[203, 295]],
#
#        [[204, 294]],
#
#        [[207, 294]],
#
#        [[207, 291]],
#
#        [[208, 290]],
#
#        [[208, 282]],
#
#        [[196, 282]],
#
#        [[195, 283]],
#
#        [[194, 282]],
#
#        [[186, 282]],
#
#        [[185, 281]],
#
#        [[182, 281]],
#
#        [[181, 282]],
#
#        [[175, 282]],
#
#        [[174, 281]]], dtype=int32), array([[[  8, 410]],
#
#        [[  7, 411]],
#
#        [[  5, 411]],
#
#        [[  4, 412]],
#
#        [[  0, 412]],
#
#        [[  4, 412]],
#
#        [[  5, 411]],
#
#        [[ 10, 411]],
#
#        [[ 11, 412]],
#
#        [[ 11, 415]],
#
#        [[ 12, 416]],
#
#        [[ 12, 420]],
#
#        [[ 13, 421]],
#
#        [[ 13, 425]],
#
#        [[ 14, 426]],
#
#        [[ 14, 430]],
#
#        [[ 15, 431]],
#
#        [[ 15, 434]],
#
#        [[ 12, 437]],
#
#        [[ 11, 436]],
#
#        [[  9, 436]],
#
#        [[  8, 437]],
#
#        [[  3, 437]],
#
#        [[  1, 435]],
#
#        [[  1, 434]],
#
#        [[  1, 435]],
#
#        [[  2, 436]],
#
#        [[  1, 437]],
#
#        [[  2, 438]],
#
#        [[  3, 437]],
#
#        [[  9, 437]],
#
#        [[ 10, 436]],
#
#        [[ 11, 436]],
#
#        [[ 12, 437]],
#
#        [[ 12, 442]],
#
#        [[ 11, 443]],
#
#        [[ 11, 445]],
#
#        [[  9, 447]],
#
#        [[  7, 447]],
#
#        [[  6, 448]],
#
#        [[  1, 448]],
#
#        [[  0, 449]],
#
#        [[  1, 448]],
#
#        [[  6, 448]],
#
#        [[  7, 447]],
#
#        [[ 10, 447]],
#
#        [[ 11, 446]],
#
#        [[ 11, 443]],
#
#        [[ 13, 441]],
#
#        [[ 15, 441]],
#
#        [[ 17, 443]],
#
#        [[ 20, 443]],
#
#        [[ 21, 444]],
#
#        [[ 20, 445]],
#
#        [[ 17, 445]],
#
#        [[ 16, 446]],
#
#        [[ 15, 445]],
#
#        [[ 15, 444]],
#
#        [[ 15, 445]],
#
#        [[ 16, 446]],
#
#        [[ 13, 449]],
#
#        [[ 12, 448]],
#
#        [[ 13, 449]],
#
#        [[ 12, 450]],
#
#        [[ 13, 449]],
#
#        [[ 14, 449]],
#
#        [[ 18, 445]],
#
#        [[ 21, 445]],
#
#        [[ 21, 443]],
#
#        [[ 18, 443]],
#
#        [[ 16, 441]],
#
#        [[ 13, 441]],
#
#        [[ 12, 440]],
#
#        [[ 12, 438]],
#
#        [[ 14, 436]],
#
#        [[ 14, 435]],
#
#        [[ 15, 434]],
#
#        [[ 16, 435]],
#
#        [[ 21, 435]],
#
#        [[ 22, 434]],
#
#        [[ 48, 434]],
#
#        [[ 49, 433]],
#
#        [[ 50, 434]],
#
#        [[ 51, 434]],
#
#        [[ 52, 433]],
#
#        [[ 59, 433]],
#
#        [[ 61, 435]],
#
#        [[ 61, 452]],
#
#        [[ 60, 453]],
#
#        [[ 53, 453]],
#
#        [[ 52, 454]],
#
#        [[ 51, 453]],
#
#        [[ 44, 453]],
#
#        [[ 43, 454]],
#
#        [[ 23, 454]],
#
#        [[ 22, 455]],
#
#        [[ 21, 454]],
#
#        [[ 16, 454]],
#
#        [[ 15, 455]],
#
#        [[ 13, 455]],
#
#        [[ 12, 456]],
#
#        [[ 11, 456]],
#
#        [[ 11, 467]],
#
#        [[ 12, 468]],
#
#        [[ 12, 469]],
#
#        [[ 13, 470]],
#
#        [[ 20, 470]],
#
#        [[ 21, 469]],
#
#        [[ 23, 469]],
#
#        [[ 24, 470]],
#
#        [[ 30, 470]],
#
#        [[ 31, 469]],
#
#        [[ 35, 469]],
#
#        [[ 36, 470]],
#
#        [[ 38, 470]],
#
#        [[ 39, 469]],
#
#        [[ 61, 469]],
#
#        [[ 62, 470]],
#
#        [[ 62, 477]],
#
#        [[ 64, 479]],
#
#        [[ 63, 480]],
#
#        [[ 63, 483]],
#
#        [[ 62, 484]],
#
#        [[ 62, 485]],
#
#        [[ 63, 486]],
#
#        [[ 63, 488]],
#
#        [[ 62, 489]],
#
#        [[ 63, 490]],
#
#        [[ 62, 491]],
#
#        [[ 62, 492]],
#
#        [[ 63, 493]],
#
#        [[ 62, 494]],
#
#        [[ 63, 495]],
#
#        [[ 63, 496]],
#
#        [[ 64, 496]],
#
#        [[ 65, 497]],
#
#        [[ 65, 498]],
#
#        [[ 66, 499]],
#
#        [[ 64, 501]],
#
#        [[ 63, 500]],
#
#        [[ 62, 500]],
#
#        [[ 61, 501]],
#
#        [[ 60, 501]],
#
#        [[ 59, 502]],
#
#        [[ 58, 501]],
#
#        [[ 58, 498]],
#
#        [[ 56, 496]],
#
#        [[ 56, 495]],
#
#        [[ 55, 494]],
#
#        [[ 55, 492]],
#
#        [[ 47, 492]],
#
#        [[ 47, 493]],
#
#        [[ 48, 494]],
#
#        [[ 48, 497]],
#
#        [[ 50, 499]],
#
#        [[ 50, 500]],
#
#        [[ 57, 500]],
#
#        [[ 59, 502]],
#
#        [[ 58, 503]],
#
#        [[ 49, 503]],
#
#        [[ 47, 501]],
#
#        [[ 47, 499]],
#
#        [[ 46, 498]],
#
#        [[ 46, 497]],
#
#        [[ 45, 496]],
#
#        [[ 45, 493]],
#
#        [[ 44, 492]],
#
#        [[ 37, 492]],
#
#        [[ 37, 495]],
#
#        [[ 38, 496]],
#
#        [[ 38, 498]],
#
#        [[ 39, 499]],
#
#        [[ 39, 502]],
#
#        [[ 38, 503]],
#
#        [[ 36, 501]],
#
#        [[ 36, 499]],
#
#        [[ 35, 498]],
#
#        [[ 35, 496]],
#
#        [[ 34, 495]],
#
#        [[ 34, 493]],
#
#        [[ 26, 493]],
#
#        [[ 26, 496]],
#
#        [[ 27, 497]],
#
#        [[ 27, 498]],
#
#        [[ 28, 499]],
#
#        [[ 28, 502]],
#
#        [[ 27, 503]],
#
#        [[ 25, 501]],
#
#        [[ 25, 499]],
#
#        [[ 24, 498]],
#
#        [[ 24, 496]],
#
#        [[ 23, 495]],
#
#        [[ 23, 493]],
#
#        [[ 15, 493]],
#
#        [[ 15, 496]],
#
#        [[ 16, 497]],
#
#        [[ 16, 499]],
#
#        [[ 17, 500]],
#
#        [[ 17, 501]],
#
#        [[ 16, 502]],
#
#        [[  5, 502]],
#
#        [[  4, 503]],
#
#        [[  2, 503]],
#
#        [[  1, 502]],
#
#        [[  0, 503]],
#
#        [[  1, 502]],
#
#        [[  2, 503]],
#
#        [[  4, 503]],
#
#        [[  5, 502]],
#
#        [[ 18, 502]],
#
#        [[ 19, 503]],
#
#        [[ 20, 502]],
#
#        [[ 21, 503]],
#
#        [[ 22, 502]],
#
#        [[ 23, 502]],
#
#        [[ 24, 503]],
#
#        [[ 25, 502]],
#
#        [[ 26, 503]],
#
#        [[ 27, 503]],
#
#        [[ 28, 502]],
#
#        [[ 29, 502]],
#
#        [[ 30, 503]],
#
#        [[ 31, 502]],
#
#        [[ 37, 502]],
#
#        [[ 38, 503]],
#
#        [[ 39, 502]],
#
#        [[ 40, 502]],
#
#        [[ 41, 503]],
#
#        [[ 45, 503]],
#
#        [[ 46, 502]],
#
#        [[ 48, 502]],
#
#        [[ 49, 503]],
#
#        [[ 58, 503]],
#
#        [[ 59, 502]],
#
#        [[ 60, 502]],
#
#        [[ 62, 500]],
#
#        [[ 63, 500]],
#
#        [[ 64, 501]],
#
#        [[ 65, 500]],
#
#        [[ 66, 500]],
#
#        [[ 66, 499]],
#
#        [[ 65, 498]],
#
#        [[ 65, 497]],
#
#        [[ 64, 496]],
#
#        [[ 65, 495]],
#
#        [[ 66, 495]],
#
#        [[ 66, 491]],
#
#        [[ 65, 490]],
#
#        [[ 65, 488]],
#
#        [[ 66, 487]],
#
#        [[ 66, 486]],
#
#        [[ 65, 487]],
#
#        [[ 65, 491]],
#
#        [[ 66, 492]],
#
#        [[ 66, 494]],
#
#        [[ 64, 496]],
#
#        [[ 62, 494]],
#
#        [[ 63, 493]],
#
#        [[ 62, 492]],
#
#        [[ 62, 491]],
#
#        [[ 63, 490]],
#
#        [[ 62, 489]],
#
#        [[ 63, 488]],
#
#        [[ 63, 486]],
#
#        [[ 62, 485]],
#
#        [[ 64, 483]],
#
#        [[ 65, 484]],
#
#        [[ 66, 483]],
#
#        [[ 67, 483]],
#
#        [[ 69, 481]],
#
#        [[ 70, 481]],
#
#        [[ 71, 482]],
#
#        [[ 71, 483]],
#
#        [[ 69, 485]],
#
#        [[ 69, 487]],
#
#        [[ 68, 488]],
#
#        [[ 68, 491]],
#
#        [[ 69, 492]],
#
#        [[ 69, 491]],
#
#        [[ 71, 489]],
#
#        [[ 72, 489]],
#
#        [[ 71, 489]],
#
#        [[ 69, 491]],
#
#        [[ 68, 490]],
#
#        [[ 68, 489]],
#
#        [[ 70, 487]],
#
#        [[ 69, 486]],
#
#        [[ 69, 485]],
#
#        [[ 71, 483]],
#
#        [[ 73, 485]],
#
#        [[ 74, 485]],
#
#        [[ 76, 487]],
#
#        [[ 76, 488]],
#
#        [[ 75, 489]],
#
#        [[ 74, 489]],
#
#        [[ 74, 490]],
#
#        [[ 75, 491]],
#
#        [[ 74, 492]],
#
#        [[ 74, 493]],
#
#        [[ 73, 494]],
#
#        [[ 72, 493]],
#
#        [[ 71, 494]],
#
#        [[ 69, 494]],
#
#        [[ 68, 495]],
#
#        [[ 68, 496]],
#
#        [[ 69, 496]],
#
#        [[ 70, 497]],
#
#        [[ 69, 498]],
#
#        [[ 71, 500]],
#
#        [[ 70, 501]],
#
#        [[ 70, 502]],
#
#        [[ 69, 503]],
#
#        [[ 68, 503]],
#
#        [[ 67, 502]],
#
#        [[ 66, 502]],
#
#        [[ 67, 503]],
#
#        [[ 66, 504]],
#
#        [[ 64, 504]],
#
#        [[ 63, 503]],
#
#        [[ 62, 503]],
#
#        [[ 62, 504]],
#
#        [[ 63, 503]],
#
#        [[ 64, 504]],
#
#        [[ 66, 504]],
#
#        [[ 67, 503]],
#
#        [[ 69, 503]],
#
#        [[ 70, 504]],
#
#        [[ 70, 505]],
#
#        [[ 72, 505]],
#
#        [[ 74, 503]],
#
#        [[ 76, 503]],
#
#        [[ 77, 502]],
#
#        [[ 77, 501]],
#
#        [[ 78, 500]],
#
#        [[ 78, 497]],
#
#        [[ 70, 497]],
#
#        [[ 68, 495]],
#
#        [[ 69, 494]],
#
#        [[ 73, 494]],
#
#        [[ 74, 493]],
#
#        [[ 75, 493]],
#
#        [[ 76, 494]],
#
#        [[ 78, 494]],
#
#        [[ 79, 495]],
#
#        [[ 80, 495]],
#
#        [[ 81, 496]],
#
#        [[ 85, 496]],
#
#        [[ 86, 495]],
#
#        [[ 98, 495]],
#
#        [[100, 497]],
#
#        [[100, 503]],
#
#        [[101, 503]],
#
#        [[100, 502]],
#
#        [[100, 496]],
#
#        [[ 99, 495]],
#
#        [[ 85, 495]],
#
#        [[ 84, 496]],
#
#        [[ 82, 496]],
#
#        [[ 80, 494]],
#
#        [[ 80, 493]],
#
#        [[ 81, 492]],
#
#        [[ 81, 484]],
#
#        [[ 77, 484]],
#
#        [[ 78, 484]],
#
#        [[ 79, 485]],
#
#        [[ 79, 488]],
#
#        [[ 80, 487]],
#
#        [[ 81, 488]],
#
#        [[ 81, 489]],
#
#        [[ 80, 490]],
#
#        [[ 78, 490]],
#
#        [[ 78, 492]],
#
#        [[ 78, 491]],
#
#        [[ 79, 490]],
#
#        [[ 80, 490]],
#
#        [[ 81, 491]],
#
#        [[ 80, 492]],
#
#        [[ 80, 494]],
#
#        [[ 79, 495]],
#
#        [[ 78, 494]],
#
#        [[ 77, 494]],
#
#        [[ 75, 492]],
#
#        [[ 75, 491]],
#
#        [[ 74, 490]],
#
#        [[ 75, 489]],
#
#        [[ 76, 489]],
#
#        [[ 76, 487]],
#
#        [[ 71, 482]],
#
#        [[ 71, 481]],
#
#        [[ 72, 480]],
#
#        [[ 73, 480]],
#
#        [[ 74, 479]],
#
#        [[ 75, 480]],
#
#        [[ 75, 481]],
#
#        [[ 76, 480]],
#
#        [[ 77, 480]],
#
#        [[ 78, 481]],
#
#        [[ 78, 482]],
#
#        [[ 78, 481]],
#
#        [[ 79, 480]],
#
#        [[ 81, 482]],
#
#        [[ 80, 481]],
#
#        [[ 81, 480]],
#
#        [[ 76, 480]],
#
#        [[ 75, 479]],
#
#        [[ 73, 479]],
#
#        [[ 71, 481]],
#
#        [[ 68, 481]],
#
#        [[ 66, 483]],
#
#        [[ 65, 482]],
#
#        [[ 65, 481]],
#
#        [[ 66, 480]],
#
#        [[ 64, 478]],
#
#        [[ 63, 478]],
#
#        [[ 62, 477]],
#
#        [[ 62, 469]],
#
#        [[ 39, 469]],
#
#        [[ 38, 470]],
#
#        [[ 36, 470]],
#
#        [[ 35, 469]],
#
#        [[ 31, 469]],
#
#        [[ 30, 470]],
#
#        [[ 24, 470]],
#
#        [[ 23, 469]],
#
#        [[ 21, 469]],
#
#        [[ 20, 470]],
#
#        [[ 13, 470]],
#
#        [[ 12, 469]],
#
#        [[ 12, 468]],
#
#        [[ 11, 467]],
#
#        [[ 11, 457]],
#
#        [[ 13, 455]],
#
#        [[ 15, 455]],
#
#        [[ 16, 454]],
#
#        [[ 21, 454]],
#
#        [[ 22, 455]],
#
#        [[ 23, 454]],
#
#        [[ 43, 454]],
#
#        [[ 44, 453]],
#
#        [[ 51, 453]],
#
#        [[ 52, 454]],
#
#        [[ 53, 453]],
#
#        [[ 61, 453]],
#
#        [[ 61, 435]],
#
#        [[ 60, 434]],
#
#        [[ 60, 433]],
#
#        [[ 52, 433]],
#
#        [[ 51, 434]],
#
#        [[ 50, 434]],
#
#        [[ 49, 433]],
#
#        [[ 48, 434]],
#
#        [[ 22, 434]],
#
#        [[ 21, 435]],
#
#        [[ 17, 435]],
#
#        [[ 15, 433]],
#
#        [[ 16, 432]],
#
#        [[ 27, 432]],
#
#        [[ 28, 431]],
#
#        [[ 54, 431]],
#
#        [[ 55, 430]],
#
#        [[ 60, 430]],
#
#        [[ 61, 429]],
#
#        [[ 61, 425]],
#
#        [[ 60, 424]],
#
#        [[ 60, 418]],
#
#        [[ 61, 417]],
#
#        [[ 60, 416]],
#
#        [[ 60, 412]],
#
#        [[ 58, 410]],
#
#        [[ 57, 411]],
#
#        [[ 50, 411]],
#
#        [[ 49, 410]],
#
#        [[ 48, 411]],
#
#        [[ 23, 411]],
#
#        [[ 22, 412]],
#
#        [[ 21, 411]],
#
#        [[ 17, 411]],
#
#        [[ 16, 412]],
#
#        [[ 13, 412]],
#
#        [[ 12, 413]],
#
#        [[ 11, 412]],
#
#        [[ 11, 411]],
#
#        [[  9, 411]]], dtype=int32), array([[[290, 141]],
#
#        [[290, 143]],
#
#        [[291, 144]],
#
#        ...,
#
#        [[295, 143]],
#
#        [[295, 142]],
#
#        [[294, 141]]], dtype=int32), array([[[214, 118]],
#
#        [[214, 124]],
#
#        [[213, 125]],
#
#        ...,
#
#        [[213, 136]],
#
#        [[213, 125]],
#
#        [[214, 124]]], dtype=int32), array([[[553, 244]],
#
#        [[554, 243]],
#
#        [[562, 243]],
#
#        [[563, 244]],
#
#        [[563, 250]],
#
#        [[564, 251]],
#
#        [[564, 262]],
#
#        [[565, 263]],
#
#        [[565, 275]],
#
#        [[566, 276]],
#
#        [[566, 282]],
#
#        [[567, 283]],
#
#        [[565, 285]],
#
#        [[564, 285]],
#
#        [[563, 284]],
#
#        [[560, 284]],
#
#        [[560, 290]],
#
#        [[562, 292]],
#
#        [[562, 294]],
#
#        [[563, 295]],
#
#        [[563, 296]],
#
#        [[562, 297]],
#
#        [[563, 296]],
#
#        [[564, 297]],
#
#        [[564, 299]],
#
#        [[563, 300]],
#
#        [[562, 299]],
#
#        [[556, 299]],
#
#        [[553, 296]],
#
#        [[554, 297]],
#
#        [[554, 298]],
#
#        [[555, 299]],
#
#        [[562, 299]],
#
#        [[563, 300]],
#
#        [[563, 302]],
#
#        [[565, 304]],
#
#        [[565, 307]],
#
#        [[566, 308]],
#
#        [[566, 313]],
#
#        [[571, 313]],
#
#        [[572, 314]],
#
#        [[572, 317]],
#
#        [[571, 318]],
#
#        [[571, 323]],
#
#        [[570, 324]],
#
#        [[566, 324]],
#
#        [[565, 325]],
#
#        [[564, 324]],
#
#        [[563, 324]],
#
#        [[562, 323]],
#
#        [[562, 316]],
#
#        [[561, 315]],
#
#        [[561, 314]],
#
#        [[556, 314]],
#
#        [[555, 315]],
#
#        [[553, 315]],
#
#        [[551, 317]],
#
#        [[547, 317]],
#
#        [[546, 318]],
#
#        [[542, 318]],
#
#        [[546, 318]],
#
#        [[547, 317]],
#
#        [[551, 317]],
#
#        [[553, 319]],
#
#        [[553, 324]],
#
#        [[552, 325]],
#
#        [[552, 328]],
#
#        [[551, 329]],
#
#        [[544, 329]],
#
#        [[543, 328]],
#
#        [[543, 322]],
#
#        [[542, 321]],
#
#        [[542, 320]],
#
#        [[542, 321]],
#
#        [[543, 322]],
#
#        [[543, 328]],
#
#        [[542, 329]],
#
#        [[540, 329]],
#
#        [[539, 328]],
#
#        [[539, 327]],
#
#        [[540, 326]],
#
#        [[539, 326]],
#
#        [[538, 325]],
#
#        [[538, 323]],
#
#        [[537, 322]],
#
#        [[537, 317]],
#
#        [[538, 316]],
#
#        [[537, 315]],
#
#        [[537, 308]],
#
#        [[539, 306]],
#
#        [[540, 306]],
#
#        [[541, 307]],
#
#        [[541, 314]],
#
#        [[542, 315]],
#
#        [[543, 314]],
#
#        [[544, 315]],
#
#        [[545, 315]],
#
#        [[546, 314]],
#
#        [[550, 314]],
#
#        [[551, 313]],
#
#        [[551, 306]],
#
#        [[550, 305]],
#
#        [[550, 304]],
#
#        [[549, 304]],
#
#        [[548, 303]],
#
#        [[545, 303]],
#
#        [[543, 301]],
#
#        [[543, 300]],
#
#        [[542, 299]],
#
#        [[542, 298]],
#
#        [[541, 297]],
#
#        [[541, 286]],
#
#        [[540, 285]],
#
#        [[540, 275]],
#
#        [[539, 274]],
#
#        [[539, 271]],
#
#        [[540, 270]],
#
#        [[539, 269]],
#
#        [[539, 256]],
#
#        [[540, 255]],
#
#        [[540, 251]],
#
#        [[539, 250]],
#
#        [[539, 249]],
#
#        [[540, 248]],
#
#        [[540, 247]],
#
#        [[542, 245]],
#
#        [[544, 245]],
#
#        [[545, 244]]], dtype=int32), array([[[487, 117]],
#
#        [[486, 118]],
#
#        [[485, 118]],
#
#        ...,
#
#        [[491, 117]],
#
#        [[490, 118]],
#
#        [[488, 118]]], dtype=int32)]
