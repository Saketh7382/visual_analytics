# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import datetime
from pathlib import Path
# Out:
# /home/saketh/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
from classes.salesAnalyzer import LSTM
from classes.weatherAnalyzer import LSTM1

# %%
def sliding_windows(data, seq_length):
    x = []

    for i in range(data-seq_length):
        _x = data[i:(i+seq_length)]
        x.append(_x)

    return np.array(x)

# %%
sliding_windows(10,5)
# Out:
# 0 5
# 1 6
# 2 7
# 3 8
# 4 9

# %%
def RMSE(data_predict,dataY_plot):
    c = 0
    for i in range(len(data_predict)):
        c = c + abs(data_predict[i][0] - dataY_plot[i][0]) ** 2
    
    return (c ** 0.5)/len(data_predict)

# %%
store = 1

# %%
for day in range(1000):
    if Path("./_config/sales/store-{}.csv".format(store)).is_file():
        print("Datafile exists")
        training_set = pd.read_csv("./_config/sales/store-{}.csv".format(store))
        training_set_values = training_set.iloc[:,0:1].values
    else:
        print("Creating New Datafile")
        dataset = pd.read_csv("./LSTM - Sales Pattern Analyzer/datasets/model-1/training-1.csv")
        training_set = dataset[dataset["SCRUB_STORE_NO"] == store]
        temp = training_set.iloc[:,2:3].copy()
        temp.to_csv("./_config/sales/store-{}.csv".format(store),index=False)
        training_set_values = training_set.iloc[:,2:3].values

    PATH = "./LSTM - Sales Pattern Analyzer/saved-models/model-1/saved_model_store_{}.pth".format(store)
    lstm1 = LSTM()
    lstm1.load_state_dict(torch.load(PATH))
    lstm1.eval()



    sc = MinMaxScaler()
    training_data = sc.fit_transform(training_set_values)

    seq_length = 14
    x = sliding_windows(training_data, seq_length)


    dataX = Variable(torch.Tensor(np.array(x)))

    lstm1_dataX =  dataX
    print("Shape of the data : {}".format(lstm1_dataX.shape))

    train_predict = lstm1(lstm1_dataX)

    data_predict = train_predict.data.numpy()

    data_predict = sc.inverse_transform(data_predict)

    temp = data_predict.reshape(-1).tolist()
    predictions = [int(i) for i in temp]

    temp = dataset.copy()
    originals = training_set_values.reshape(-1).tolist()
    plotY = originals[14:]

    print("RMSE of validation set: {}".format(RMSE([predictions],[plotY])))


#     plt.plot(plotY)
#     plt.plot(predictions)
#     plt.suptitle('Prediction')
#     plt.show()

    training_set.loc[len(training_set)] = [predictions[-1]]
    training_set.to_csv("./_config/sales/store-{}.csv".format(store),index=False)
    originals = pd.read_csv("./_config/sales/store-{}.csv".format(store))
    originals = originals.iloc[:,0:1].values
    originals = originals.reshape(-1).tolist()
# Out:
# Datafile exists
# Shape of the data : torch.Size([1623, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1624, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1625, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1626, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1627, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1628, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1629, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1630, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1631, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1632, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1633, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1634, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1635, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1636, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1637, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1638, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1639, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1640, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1641, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1642, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1643, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1644, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1645, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1646, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1647, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1648, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1649, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1650, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1651, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1652, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1653, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1654, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1655, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1656, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1657, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1658, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1659, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1660, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1661, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1662, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1663, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1664, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1665, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1666, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1667, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1668, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1669, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1670, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1671, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1672, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1673, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1674, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1675, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1676, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1677, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1678, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1679, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1680, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1681, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1682, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1683, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1684, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1685, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1686, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1687, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1688, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1689, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1690, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1691, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1692, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1693, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1694, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1695, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1696, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1697, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1698, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1699, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1700, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1701, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1702, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1703, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1704, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1705, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1706, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1707, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1708, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1709, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1710, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1711, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1712, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1713, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1714, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1715, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1716, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1717, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1718, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1719, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1720, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1721, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1722, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1723, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1724, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1725, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1726, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1727, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1728, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1729, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1730, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1731, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1732, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1733, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1734, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1735, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1736, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1737, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1738, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1739, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1740, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1741, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1742, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1743, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1744, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1745, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1746, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1747, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1748, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1749, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1750, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1751, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1752, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1753, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1754, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1755, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1756, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1757, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1758, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1759, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1760, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1761, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1762, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1763, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1764, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1765, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1766, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1767, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1768, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1769, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1770, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1771, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1772, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1773, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1774, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1775, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1776, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1777, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1778, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1779, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1780, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1781, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1782, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1783, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1784, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1785, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1786, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1787, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1788, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1789, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1790, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1791, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1792, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1793, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1794, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1795, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1796, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1797, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1798, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1799, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1800, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1801, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1802, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1803, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1804, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1805, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1806, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1807, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1808, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1809, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1810, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1811, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1812, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1813, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1814, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1815, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1816, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1817, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1818, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1819, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1820, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1821, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1822, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1823, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1824, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1825, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1826, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1827, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1828, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1829, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1830, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1831, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1832, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1833, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1834, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1835, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1836, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1837, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1838, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1839, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1840, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1841, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1842, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1843, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1844, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1845, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1846, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1847, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1848, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1849, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1850, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1851, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1852, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1853, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1854, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1855, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1856, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1857, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1858, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1859, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1860, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1861, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1862, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1863, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1864, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1865, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1866, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1867, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1868, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1869, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1870, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1871, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1872, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1873, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1874, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1875, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1876, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1877, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1878, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1879, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1880, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1881, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1882, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1883, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1884, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1885, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1886, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1887, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1888, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1889, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1890, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1891, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1892, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1893, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1894, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1895, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1896, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1897, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1898, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1899, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1900, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1901, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1902, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1903, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1904, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1905, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1906, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1907, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1908, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1909, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1910, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1911, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1912, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1913, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1914, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1915, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1916, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1917, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1918, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1919, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1920, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1921, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1922, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1923, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1924, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1925, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1926, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1927, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1928, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1929, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1930, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1931, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1932, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1933, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1934, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1935, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1936, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1937, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1938, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1939, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1940, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1941, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1942, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1943, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1944, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1945, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1946, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1947, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1948, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1949, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1950, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1951, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1952, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1953, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1954, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1955, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1956, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1957, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1958, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1959, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1960, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1961, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1962, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1963, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1964, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1965, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1966, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1967, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1968, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1969, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1970, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1971, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1972, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1973, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1974, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1975, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1976, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1977, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1978, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1979, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1980, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1981, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1982, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1983, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1984, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1985, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1986, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1987, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1988, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1989, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1990, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1991, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1992, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1993, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1994, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1995, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1996, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1997, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1998, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([1999, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2000, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2001, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2002, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2003, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2004, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2005, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2006, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2007, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2008, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2009, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2010, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2011, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2012, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2013, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2014, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2015, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2016, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2017, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2018, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2019, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2020, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2021, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2022, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2023, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2024, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2025, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2026, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2027, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2028, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2029, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2030, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2031, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2032, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2033, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2034, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2035, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2036, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2037, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2038, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2039, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2040, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2041, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2042, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2043, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2044, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2045, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2046, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2047, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2048, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2049, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2050, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2051, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2052, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2053, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2054, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2055, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2056, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2057, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2058, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2059, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2060, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2061, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2062, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2063, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2064, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2065, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2066, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2067, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2068, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2069, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2070, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2071, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2072, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2073, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2074, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2075, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2076, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2077, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2078, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2079, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2080, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2081, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2082, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2083, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2084, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2085, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2086, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2087, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2088, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2089, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2090, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2091, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2092, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2093, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2094, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2095, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2096, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2097, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2098, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2099, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2100, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2101, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2102, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2103, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2104, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2105, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2106, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2107, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2108, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2109, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2110, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2111, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2112, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2113, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2114, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2115, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2116, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2117, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2118, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2119, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2120, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2121, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2122, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2123, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2124, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2125, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2126, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2127, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2128, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2129, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2130, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2131, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2132, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2133, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2134, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2135, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2136, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2137, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2138, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2139, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2140, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2141, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2142, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2143, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2144, 14, 1])
# ...
# Shape of the data : torch.Size([2449, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2450, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2451, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2452, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2453, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2454, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2455, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2456, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2457, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2458, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2459, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2460, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2461, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2462, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2463, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2464, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2465, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2466, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2467, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2468, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2469, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2470, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2471, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2472, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2473, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2474, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2475, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2476, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2477, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2478, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2479, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2480, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2481, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2482, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2483, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2484, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2485, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2486, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2487, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2488, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2489, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2490, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2491, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2492, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2493, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2494, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2495, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2496, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2497, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2498, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2499, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2500, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2501, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2502, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2503, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2504, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2505, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2506, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2507, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2508, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2509, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2510, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2511, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2512, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2513, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2514, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2515, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2516, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2517, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2518, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2519, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2520, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2521, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2522, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2523, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2524, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2525, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2526, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2527, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2528, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2529, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2530, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2531, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2532, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2533, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2534, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2535, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2536, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2537, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2538, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2539, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2540, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2541, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2542, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2543, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2544, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2545, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2546, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2547, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2548, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2549, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2550, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2551, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2552, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2553, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2554, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2555, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2556, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2557, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2558, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2559, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2560, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2561, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2562, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2563, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2564, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2565, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2566, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2567, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2568, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2569, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2570, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2571, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2572, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2573, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2574, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2575, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2576, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2577, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2578, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2579, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2580, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2581, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2582, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2583, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2584, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2585, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2586, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2587, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2588, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2589, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2590, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2591, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2592, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2593, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2594, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2595, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2596, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2597, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2598, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2599, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2600, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2601, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2602, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2603, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2604, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2605, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2606, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2607, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2608, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2609, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2610, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2611, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2612, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2613, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2614, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2615, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2616, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2617, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2618, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2619, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2620, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2621, 14, 1])
# RMSE of validation set: 571.0
# Datafile exists
# Shape of the data : torch.Size([2622, 14, 1])
# RMSE of validation set: 571.0

# %% [markdown]
# # Weather Analyzer

# %%
forecast = pd.read_csv("./LSTM - Weather Sales Forecast/datasets/forecasting.csv")

merged = pd.read_csv("./LSTM - Weather Sales Forecast/datasets/merged.csv")
training_dataset = pd.read_csv("./LSTM - Weather Sales Forecast/datasets/training.csv")

# %%
store = 1

# %%
cols = ['DOY_STD',
       'AVG_OF__DAILY_AVG_TEMPERATURE_AIR_F',
       'AVG_OF__DAILY_AVG_TEMPERATURE_WETBULB_F',
       'AVG_OF__DAILY_AVG_TEMPERATURE_DEWPOINT_F',
       'AVG_OF__DAILY_AVG_TEMPERATURE_FEELSLIKE_F',
       'AVG_OF__DAILY_AVG_HUMIDITY_RELATIVE_PCT',
       'AVG_OF__DAILY_AVG_HUMIDITY_SPECIFIC_GPKG',
       'AVG_OF__DAILY_AVG_PRESSURE_SURFACE_MB',
       'AVG_OF__DAILY_AVG_PRESSURE_MEAN_SEA_LEVEL_MB',
       'AVG_OF__DAILY_AVG_WIND_SPEED_10M_MPH',
       'AVG_VEC_OF__DAILY_AVG_VEC_WIND_DIRECTION_10M_DEG',
       'AVG_VEC_OF__DAILY_AVG_VEC_WIND_DIRECTION_80M_DEG',
       'AVG_VEC_OF__DAILY_AVG_VEC_WIND_DIRECTION_100M_DEG',
       'AVG_OF__POS_DAILY_TOT_PRECIPITATION_IN',
       'AVG_OF__POS_DAILY_TOT_SNOWFALL_IN',
       'AVG_OF__DAILY_AVG_CLOUD_COVER_TOT_PCT',
       'AVG_OF__DAILY_AVG_RADIATION_SOLAR_TOTAL_WPM2',
       'AVG_OF__DAILY_TOT_RADIATION_SOLAR_TOTAL_WPM2']

# %%
for store in range(1,21):
    print("_____STORE NUM. {}_____".format(store))
    
    PATH = "./LSTM - Weather Sales Forecast/saved-models/model-1/saved_model_store_{}.pth".format(store)
    lstm2 = LSTM1()
    lstm2.load_state_dict(torch.load(PATH))
    lstm2.eval()
    training = pd.read_csv("./LSTM - Weather Sales Forecast/datasets/merged.csv")
    training = training[training["SCRUB_STORE_NO"] == store].iloc[:,2:3]
    
    copy_dataset = forecast.copy()
    copy_dataset = copy_dataset[copy_dataset["SCRUB_STORE_NO"] == store].iloc[:,2:]


    X = copy_dataset
    y = training

    mm = MinMaxScaler()
    ss = StandardScaler()

    X_ss = ss.fit_transform(X)
    y_mm = mm.fit_transform(y)

    data_X = Variable(torch.Tensor(X_ss))

    data_X_tensors = torch.reshape(data_X,   (data_X.shape[0], 1, data_X.shape[1]))
    print("data Shape", data_X_tensors.shape) 

    outputs = lstm2(data_X_tensors)


    data_predict = outputs.data.numpy()
    data_predict = mm.inverse_transform(data_predict)

    print("Shape of data predicted {}".format(data_predict.shape))


    plt.figure(figsize=(10,6))

    plt.plot(data_predict)
    plt.suptitle('Prediction')
    plt.show()
    
    copy_dataset["FORECAST"] = data_predict.astype(int)
    copy_dataset.to_csv("./predictions/weatherAnalyzer/forecast/store_{}.csv".format(store),index=False)
# Out:
# _____STORE NUM. 1_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 2_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 3_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 4_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 5_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 6_____
# data Shape torch.Size([15, 1, 19])
# Shape of data predicted (15, 1)
# _____STORE NUM. 7_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 8_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 9_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 10_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 11_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 12_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 13_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 14_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 15_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 16_____
# data Shape torch.Size([15, 1, 19])
# Shape of data predicted (15, 1)
# _____STORE NUM. 17_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 18_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)
# _____STORE NUM. 19_____
# data Shape torch.Size([15, 1, 19])
# Shape of data predicted (15, 1)
# _____STORE NUM. 20_____
# data Shape torch.Size([16, 1, 19])
# Shape of data predicted (16, 1)

# %%
for store in range(1,21):
    print("_____STORE NUM. {}_____".format(store))
    
    PATH = "./LSTM - Weather Sales Forecast/saved-models/model-1/saved_model_store_{}.pth".format(store)
    lstm2 = LSTM1()
    lstm2.load_state_dict(torch.load(PATH))
    lstm2.eval()
    training = pd.read_csv("./LSTM - Weather Sales Forecast/datasets/merged.csv")
    training = training[training["SCRUB_STORE_NO"] == store].iloc[:,2:3]
    
    copy_dataset = training_dataset[training_dataset["SCRUB_STORE_NO"] == store].iloc[:,3:].copy()
    

    X = copy_dataset
    y = training

    mm = MinMaxScaler()
    ss = StandardScaler()

    X_ss = ss.fit_transform(X)
    y_mm = mm.fit_transform(y)

    data_X = Variable(torch.Tensor(X_ss))

    data_X_tensors = torch.reshape(data_X,   (data_X.shape[0], 1, data_X.shape[1]))
    print("data Shape", data_X_tensors.shape) 

    outputs = lstm2(data_X_tensors)


    data_predict = outputs.data.numpy()
    data_predict = mm.inverse_transform(data_predict)

    print("Shape of data predicted {}".format(data_predict.shape))


    plt.figure(figsize=(10,6))

    plt.plot(data_predict)
    plt.suptitle('Prediction')
    plt.show()
    
    copy_dataset["FORECAST"] = data_predict.astype(int)
    copy_dataset.to_csv("./predictions/weatherAnalyzer/total/store_{}.csv".format(store),index=FalseZ)
# Out:
# _____STORE NUM. 1_____
# data Shape torch.Size([1636, 1, 19])
# Shape of data predicted (1636, 1)
# _____STORE NUM. 2_____
# data Shape torch.Size([1488, 1, 19])
# Shape of data predicted (1488, 1)
# _____STORE NUM. 3_____
# data Shape torch.Size([1608, 1, 19])
# Shape of data predicted (1608, 1)
# _____STORE NUM. 4_____
# data Shape torch.Size([1641, 1, 19])
# Shape of data predicted (1641, 1)
# _____STORE NUM. 5_____
# data Shape torch.Size([1575, 1, 19])
# Shape of data predicted (1575, 1)
# _____STORE NUM. 6_____
# data Shape torch.Size([1646, 1, 19])
# Shape of data predicted (1646, 1)
# _____STORE NUM. 7_____
# data Shape torch.Size([1601, 1, 19])
# Shape of data predicted (1601, 1)
# _____STORE NUM. 8_____
# data Shape torch.Size([1450, 1, 19])
# Shape of data predicted (1450, 1)
# _____STORE NUM. 9_____
# data Shape torch.Size([1567, 1, 19])
# Shape of data predicted (1567, 1)
# _____STORE NUM. 10_____
# data Shape torch.Size([1629, 1, 19])
# Shape of data predicted (1629, 1)
# _____STORE NUM. 11_____
# data Shape torch.Size([1415, 1, 19])
# Shape of data predicted (1415, 1)
# _____STORE NUM. 12_____
# data Shape torch.Size([1657, 1, 19])
# Shape of data predicted (1657, 1)
# _____STORE NUM. 13_____
# data Shape torch.Size([1558, 1, 19])
# Shape of data predicted (1558, 1)
# _____STORE NUM. 14_____
# data Shape torch.Size([1575, 1, 19])
# Shape of data predicted (1575, 1)
# _____STORE NUM. 15_____
# data Shape torch.Size([1593, 1, 19])
# Shape of data predicted (1593, 1)
# _____STORE NUM. 16_____
# data Shape torch.Size([1572, 1, 19])
# Shape of data predicted (1572, 1)
# _____STORE NUM. 17_____
# data Shape torch.Size([1617, 1, 19])
# Shape of data predicted (1617, 1)
# _____STORE NUM. 18_____
# data Shape torch.Size([1601, 1, 19])
# Shape of data predicted (1601, 1)
# _____STORE NUM. 19_____
# data Shape torch.Size([1425, 1, 19])
# Shape of data predicted (1425, 1)
# _____STORE NUM. 20_____
# data Shape torch.Size([1467, 1, 19])
# Shape of data predicted (1467, 1)

# %% [markdown]
# # Sales Analyzer

# %%
store = 1

# %%
forecast = pd.read_csv("./predictions/weatherAnalyzer/forecast/store_{}.csv".format(store))
total = pd.read_csv("./predictions/weatherAnalyzer/total/store_{}.csv".format(store))
dataset = pd.concat([total,forecast],ignore_index=True)

# %%
for store in range(1,21):
    print("_____STORE NUM. {}_____".format(store))
    
    PATH = "./LSTM - Sales Pattern Analyzer/saved-models/model-1/saved_model_store_{}.pth".format(store)
    lstm1 = LSTM()
    lstm1.load_state_dict(torch.load(PATH))
    lstm1.eval()

    training_set = dataset.iloc[:,-1:].values

    plt.plot(training_set, label = 'Sales')
    plt.suptitle('Sales of Store - {}'.format(store))
    plt.show()

    sc = MinMaxScaler()
    training_data = sc.fit_transform(training_set)

    seq_length = 14
    x, y = sliding_windows(training_data, seq_length)

    train_size = int(len(y) * 0.67)
    test_size = len(y) - train_size

    dataX = Variable(torch.Tensor(np.array(x)))
    dataY = Variable(torch.Tensor(np.array(y)))

    trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
    trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

    testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
    testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

    '''-------------------------------------------------------------------------------------------------------------'''

    logger = Logger("./logs/model-1/training_log_store_{}.txt".format(store))

    PATH='./saved-models/model-1/saved_model_store_{}.pth'.format(store)

    num_epochs = 4000
    learning_rate = 0.01

    input_size = 1
    hidden_size = 15
    num_layers = 1

    num_classes = 1

    lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

    criterion = torch.nn.MSELoss()    # mean-squared error for regression
    optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
    #optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

    min_valid_loss = np.inf

    current_threshold = 0
    cutoff_threshold = 2000

    '''Logging the parameters'''
    logger.log("\tNumber of epochs :\t{}".format(num_epochs))
    logger.log("\tLearning Rate :\t{}".format(learning_rate))
    logger.log("\tInput size : {}".format(input_size))
    logger.log("\tNumber of layers : {}".format(num_layers))
    logger.log("\tNumber of classes : {}".format(num_classes))
    logger.log("\tLoss function : {}".format("MSE"))
    logger.log("\tOptimizer : {}".format("ADAM"))

    # Train the model

    logger.log("\t :Training model\n------------------")
    for epoch in range(num_epochs):
        lstm.train()
        '''---training---'''
        train_loss = 0.0
        outputs = lstm(trainX)
        optimizer.zero_grad()

        # obtain the loss function
        loss = criterion(outputs, trainY)

        loss.backward()

        optimizer.step()

        train_loss = loss.item()

        '''---validation---'''
        valid_loss = 0.0
        lstm.eval() 

        outputs = lstm(testX)

        loss = criterion(outputs,testY)

        valid_loss += loss.item()

        if (epoch + 1) % 100 == 0:
            print('Epoch %d \t\t Training Loss: %1.5f \t\t Validation Loss: %1.5f'%(epoch+1,train_loss,valid_loss))
            logger.log('Epoch %d \t\t Training Loss: %1.5f \t\t Validation Loss: %1.5f'%(epoch+1,train_loss,valid_loss))

        if min_valid_loss > valid_loss:
            current_threshold = 0
            print(f'Validation Loss Decreased({min_valid_loss:1.5f}--->{valid_loss:1.5f}) \t Saving The Model')
            logger.log(f'Validation Loss Decreased({min_valid_loss:1.5f}--->{valid_loss:1.5f}) \t Saving The Model')
            min_valid_loss = valid_loss

            # Saving State Dict
            torch.save(lstm.state_dict(), PATH)
        else:
            current_threshold += 1

            if current_threshold == cutoff_threshold:
                print("Stopping the training early\t\tModel saved")
                print("\tTraining Loss: ",train_loss)
                print("\tValidation Loss: ",min_valid_loss)

                logger.log("Stopping the training early\t\tModel saved")
                logger.log("\tTraining Loss: {}".format(train_loss))
                logger.log("\tValidation Loss: {}".format(min_valid_loss))
                logger.log("\n\n\n")

                break


    lstm = LSTM(num_classes, input_size, hidden_size, num_layers)
    lstm.load_state_dict(torch.load(PATH))
    lstm.eval()

    train_predict = lstm(testX)

    data_predict = train_predict.data.numpy()
    dataY_plot = testY.data.numpy()

    data_predict = sc.inverse_transform(data_predict)
    dataY_plot = sc.inverse_transform(dataY_plot)

    plt.figure(figsize=(10,6))

    plt.axvline(x=train_size, c='r', linestyle='--')

    plt.plot(dataY_plot)
    plt.plot(data_predict)
    plt.suptitle('Prediction')
    plt.show()

    print("RMSE of validation set: {}".format(RMSE(data_predict,dataY_plot)))
    logger.log("RMSE of validation set: {}".format(RMSE(data_predict,dataY_plot)))

    train_predict = lstm(dataX)

    data_predict = train_predict.data.numpy()
    dataY_plot = dataY.data.numpy()

    data_predict = sc.inverse_transform(data_predict)
    dataY_plot = sc.inverse_transform(dataY_plot)

    print("RMSE of entire data set: {}".format(RMSE(data_predict,dataY_plot)))
    logger.log("RMSE of entire data set: {}".format(RMSE(data_predict,dataY_plot)))

    logger.log("\n\n\n")
    logger.stop()
